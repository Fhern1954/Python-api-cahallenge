# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_name=[]
lat = []
lng = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
date = []


# Loop through the list of cities and perform a request for data on each
count=0
print("Start API Call to OpenWeather Database ")
print("---------------------------------------")

for city in cities:
    try:
        count += 1
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        print(f"Processing record {count} for the city: {city}")
    
    except:
        #cities.remove(city)
        print(f"{city} not found in OpenWeather database.")
        pass

    print("---------------------------------------")
# Out:
# Start API Call to OpenWeather Database
# ---------------------------------------
# Processing record 1 for the city: saint-philippe
# ---------------------------------------
# Processing record 2 for the city: gold coast
# ---------------------------------------
# Processing record 3 for the city: atuona
# ---------------------------------------
# Processing record 4 for the city: ambon
# ---------------------------------------
# Processing record 5 for the city: ushuaia
# ---------------------------------------
# Processing record 6 for the city: riyadh
# ---------------------------------------
# Processing record 7 for the city: farsund
# ---------------------------------------
# Processing record 8 for the city: elko
# ---------------------------------------
# Processing record 9 for the city: torbay
# ---------------------------------------
# tsihombe not found in OpenWeather database.
# ---------------------------------------
# Processing record 11 for the city: manado
# ---------------------------------------
# Processing record 12 for the city: busselton
# ---------------------------------------
# Processing record 13 for the city: agadez
# ---------------------------------------
# Processing record 14 for the city: norman wells
# ---------------------------------------
# Processing record 15 for the city: muros
# ---------------------------------------
# Processing record 16 for the city: kalmunai
# ---------------------------------------
# Processing record 17 for the city: kaitangata
# ---------------------------------------
# Processing record 18 for the city: puerto ayora
# ---------------------------------------
# Processing record 19 for the city: kapaa
# ---------------------------------------
# Processing record 20 for the city: akdepe
# ---------------------------------------
# Processing record 21 for the city: katsuura
# ---------------------------------------
# Processing record 22 for the city: tiksi
# ---------------------------------------
# Processing record 23 for the city: cape town
# ---------------------------------------
# Processing record 24 for the city: carutapera
# ---------------------------------------
# Processing record 25 for the city: new norfolk
# ---------------------------------------
# taolanaro not found in OpenWeather database.
# ---------------------------------------
# Processing record 27 for the city: vavoua
# ---------------------------------------
# Processing record 28 for the city: sur
# ---------------------------------------
# belushya guba not found in OpenWeather database.
# ---------------------------------------
# Processing record 30 for the city: kodiak
# ---------------------------------------
# Processing record 31 for the city: ryotsu
# ---------------------------------------
# Processing record 32 for the city: sao joao da barra
# ---------------------------------------
# Processing record 33 for the city: launceston
# ---------------------------------------
# vaitupu not found in OpenWeather database.
# ---------------------------------------
# Processing record 35 for the city: lorengau
# ---------------------------------------
# Processing record 36 for the city: rikitea
# ---------------------------------------
# Processing record 37 for the city: esperance
# ---------------------------------------
# Processing record 38 for the city: mataura
# ---------------------------------------
# Processing record 39 for the city: mehamn
# ---------------------------------------
# Processing record 40 for the city: kongolo
# ---------------------------------------
# illoqqortoormiut not found in OpenWeather database.
# ---------------------------------------
# Processing record 42 for the city: roma
# ---------------------------------------
# Processing record 43 for the city: bengkulu
# ---------------------------------------
# Processing record 44 for the city: sheffield
# ---------------------------------------
# Processing record 45 for the city: bredasdorp
# ---------------------------------------
# Processing record 46 for the city: bethel
# ---------------------------------------
# Processing record 47 for the city: nanortalik
# ---------------------------------------
# Processing record 48 for the city: khatanga
# ---------------------------------------
# Processing record 49 for the city: luderitz
# ---------------------------------------
# Processing record 50 for the city: santa isabel do rio negro
# ---------------------------------------
# Processing record 51 for the city: beni suef
# ---------------------------------------
# Processing record 52 for the city: port alfred
# ---------------------------------------
# Processing record 53 for the city: port elizabeth
# ---------------------------------------
# Processing record 54 for the city: king city
# ---------------------------------------
# Processing record 55 for the city: lerwick
# ---------------------------------------
# Processing record 56 for the city: saint-francois
# ---------------------------------------
# Processing record 57 for the city: butaritari
# ---------------------------------------
# Processing record 58 for the city: georgetown
# ---------------------------------------
# Processing record 59 for the city: turki
# ---------------------------------------
# Processing record 60 for the city: albany
# ---------------------------------------
# Processing record 61 for the city: inongo
# ---------------------------------------
# Processing record 62 for the city: pangnirtung
# ---------------------------------------
# Processing record 63 for the city: inhambane
# ---------------------------------------
# Processing record 64 for the city: qaanaaq
# ---------------------------------------
# Processing record 65 for the city: hunterville
# ---------------------------------------
# Processing record 66 for the city: bluff
# ---------------------------------------
# Processing record 67 for the city: maldonado
# ---------------------------------------
# Processing record 68 for the city: jamestown
# ---------------------------------------
# Processing record 69 for the city: tasiilaq
# ---------------------------------------
# Processing record 70 for the city: isangel
# ---------------------------------------
# Processing record 71 for the city: saskylakh
# ---------------------------------------
# Processing record 72 for the city: barrow
# ---------------------------------------
# Processing record 73 for the city: wilmington
# ---------------------------------------
# Processing record 74 for the city: hermanus
# ---------------------------------------
# Processing record 75 for the city: vestmanna
# ---------------------------------------
# Processing record 76 for the city: rio gallegos
# ---------------------------------------
# Processing record 77 for the city: north bend
# ---------------------------------------
# Processing record 78 for the city: punta arenas
# ---------------------------------------
# Processing record 79 for the city: yankton
# ---------------------------------------
# Processing record 80 for the city: lekoni
# ---------------------------------------
# Processing record 81 for the city: yerbogachen
# ---------------------------------------
# Processing record 82 for the city: thompson
# ---------------------------------------
# Processing record 83 for the city: touros
# ---------------------------------------
# Processing record 84 for the city: arraial do cabo
# ---------------------------------------
# Processing record 85 for the city: avarua
# ---------------------------------------
# Processing record 86 for the city: kruisfontein
# ---------------------------------------
# Processing record 87 for the city: harper
# ---------------------------------------
# Processing record 88 for the city: nyurba
# ---------------------------------------
# Processing record 89 for the city: port hedland
# ---------------------------------------
# mys shmidta not found in OpenWeather database.
# ---------------------------------------
# Processing record 91 for the city: hervey bay
# ---------------------------------------
# Processing record 92 for the city: vaini
# ---------------------------------------
# Processing record 93 for the city: nikolskoye
# ---------------------------------------
# Processing record 94 for the city: yellowknife
# ---------------------------------------
# Processing record 95 for the city: charyshskoye
# ---------------------------------------
# Processing record 96 for the city: pevek
# ---------------------------------------
# Processing record 97 for the city: yartsevo
# ---------------------------------------
# Processing record 98 for the city: dikson
# ---------------------------------------
# Processing record 99 for the city: bonavista
# ---------------------------------------
# Processing record 100 for the city: castanos
# ---------------------------------------
# Processing record 101 for the city: mar del plata
# ---------------------------------------
# Processing record 102 for the city: hobart
# ---------------------------------------
# Processing record 103 for the city: talnakh
# ---------------------------------------
# Processing record 104 for the city: nobres
# ---------------------------------------
# Processing record 105 for the city: hilo
# ---------------------------------------
# Processing record 106 for the city: upernavik
# ---------------------------------------
# Processing record 107 for the city: maniitsoq
# ---------------------------------------
# Processing record 108 for the city: ishigaki
# ---------------------------------------
# Processing record 109 for the city: celestun
# ---------------------------------------
# Processing record 110 for the city: moratuwa
# ---------------------------------------
# Processing record 111 for the city: podyuga
# ---------------------------------------
# Processing record 112 for the city: disna
# ---------------------------------------
# Processing record 113 for the city: castro
# ---------------------------------------
# Processing record 114 for the city: kavaratti
# ---------------------------------------
# Processing record 115 for the city: bosaso
# ---------------------------------------
# Processing record 116 for the city: tchibanga
# ---------------------------------------
# Processing record 117 for the city: gallup
# ---------------------------------------
# Processing record 118 for the city: mahebourg
# ---------------------------------------
# Processing record 119 for the city: taoudenni
# ---------------------------------------
# hunza not found in OpenWeather database.
# ---------------------------------------
# Processing record 121 for the city: hofn
# ---------------------------------------
# Processing record 122 for the city: kozan
# ---------------------------------------
# Processing record 123 for the city: mount isa
# ---------------------------------------
# Processing record 124 for the city: grand gaube
# ---------------------------------------
# Processing record 125 for the city: ayorou
# ---------------------------------------
# Processing record 126 for the city: ribeira grande
# ---------------------------------------
# Processing record 127 for the city: faanui
# ---------------------------------------
# Processing record 128 for the city: garcia
# ---------------------------------------
# Processing record 129 for the city: murgab
# ---------------------------------------
# qandahar not found in OpenWeather database.
# ---------------------------------------
# Processing record 131 for the city: lewistown
# ---------------------------------------
# Processing record 132 for the city: saldanha
# ---------------------------------------
# tumannyy not found in OpenWeather database.
# ---------------------------------------
# saleaula not found in OpenWeather database.
# ---------------------------------------
# Processing record 135 for the city: iqaluit
# ---------------------------------------
# Processing record 136 for the city: vao
# ---------------------------------------
# Processing record 137 for the city: port-gentil
# ---------------------------------------
# Processing record 138 for the city: yanam
# ---------------------------------------
# Processing record 139 for the city: san cristobal
# ---------------------------------------
# Processing record 140 for the city: rocha
# ---------------------------------------
# Processing record 141 for the city: cherskiy
# ---------------------------------------
# Processing record 142 for the city: vangaindrano
# ---------------------------------------
# Processing record 143 for the city: axim
# ---------------------------------------
# Processing record 144 for the city: dukat
# ---------------------------------------
# Processing record 145 for the city: saint george
# ---------------------------------------
# Processing record 146 for the city: toledo
# ---------------------------------------
# Processing record 147 for the city: adrar
# ---------------------------------------
# Processing record 148 for the city: chokurdakh
# ---------------------------------------
# Processing record 149 for the city: ixtapa
# ---------------------------------------
# Processing record 150 for the city: guarapari
# ---------------------------------------
# Processing record 151 for the city: severo-kurilsk
# ---------------------------------------
# Processing record 152 for the city: fukue
# ---------------------------------------
# quetzaltepec not found in OpenWeather database.
# ---------------------------------------
# Processing record 154 for the city: hithadhoo
# ---------------------------------------
# Processing record 155 for the city: san patricio
# ---------------------------------------
# Processing record 156 for the city: quelimane
# ---------------------------------------
# amderma not found in OpenWeather database.
# ---------------------------------------
# Processing record 158 for the city: ilulissat
# ---------------------------------------
# Processing record 159 for the city: opuwo
# ---------------------------------------
# Processing record 160 for the city: vila velha
# ---------------------------------------
# Processing record 161 for the city: port blair
# ---------------------------------------
# Processing record 162 for the city: kununurra
# ---------------------------------------
# Processing record 163 for the city: hit
# ---------------------------------------
# sumbawa not found in OpenWeather database.
# ---------------------------------------
# Processing record 165 for the city: cayenne
# ---------------------------------------
# naftah not found in OpenWeather database.
# ---------------------------------------
# Processing record 167 for the city: korla
# ---------------------------------------
# Processing record 168 for the city: guerrero negro
# ---------------------------------------
# sentyabrskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 170 for the city: sumenep
# ---------------------------------------
# Processing record 171 for the city: suzuka
# ---------------------------------------
# Processing record 172 for the city: longyearbyen
# ---------------------------------------
# Processing record 173 for the city: salalah
# ---------------------------------------
# Processing record 174 for the city: adelaide
# ---------------------------------------
# Processing record 175 for the city: lebu
# ---------------------------------------
# attawapiskat not found in OpenWeather database.
# ---------------------------------------
# Processing record 177 for the city: monrovia
# ---------------------------------------
# Processing record 178 for the city: ossora
# ---------------------------------------
# Processing record 179 for the city: martinsicuro
# ---------------------------------------
# Processing record 180 for the city: mandalgovi
# ---------------------------------------
# Processing record 181 for the city: jiexiu
# ---------------------------------------
# Processing record 182 for the city: santa cruz de la palma
# ---------------------------------------
# Processing record 183 for the city: pitimbu
# ---------------------------------------
# samusu not found in OpenWeather database.
# ---------------------------------------
# Processing record 185 for the city: maroantsetra
# ---------------------------------------
# Processing record 186 for the city: bay city
# ---------------------------------------
# Processing record 187 for the city: litovko
# ---------------------------------------
# Processing record 188 for the city: aleksandrov gay
# ---------------------------------------
# Processing record 189 for the city: hamilton
# ---------------------------------------
# Processing record 190 for the city: wanlaweyn
# ---------------------------------------
# Processing record 191 for the city: hami
# ---------------------------------------
# Processing record 192 for the city: cidreira
# ---------------------------------------
# Processing record 193 for the city: vaitape
# ---------------------------------------
# Processing record 194 for the city: ventnor city
# ---------------------------------------
# Processing record 195 for the city: arica
# ---------------------------------------
# Processing record 196 for the city: san jose
# ---------------------------------------
# Processing record 197 for the city: cumbitara
# ---------------------------------------
# barentsburg not found in OpenWeather database.
# ---------------------------------------
# kundarki not found in OpenWeather database.
# ---------------------------------------
# palabuhanratu not found in OpenWeather database.
# ---------------------------------------
# Processing record 201 for the city: vestmannaeyjar
# ---------------------------------------
# Processing record 202 for the city: camaqua
# ---------------------------------------
# Processing record 203 for the city: husavik
# ---------------------------------------
# Processing record 204 for the city: nelson bay
# ---------------------------------------
# Processing record 205 for the city: shasta lake
# ---------------------------------------
# Processing record 206 for the city: los llanos de aridane
# ---------------------------------------
# Processing record 207 for the city: noumea
# ---------------------------------------
# Processing record 208 for the city: xining
# ---------------------------------------
# Processing record 209 for the city: beloha
# ---------------------------------------
# Processing record 210 for the city: chernyshevskiy
# ---------------------------------------
# Processing record 211 for the city: clyde river
# ---------------------------------------
# Processing record 212 for the city: eydhafushi
# ---------------------------------------
# Processing record 213 for the city: sipe sipe
# ---------------------------------------
# Processing record 214 for the city: pokrovsk
# ---------------------------------------
# Processing record 215 for the city: henties bay
# ---------------------------------------
# Processing record 216 for the city: pangkalanbuun
# ---------------------------------------
# Processing record 217 for the city: leningradskiy
# ---------------------------------------
# kuche not found in OpenWeather database.
# ---------------------------------------
# Processing record 219 for the city: tshane
# ---------------------------------------
# Processing record 220 for the city: lufilufi
# ---------------------------------------
# Processing record 221 for the city: komsomolskiy
# ---------------------------------------
# kerteh not found in OpenWeather database.
# ---------------------------------------
# Processing record 223 for the city: chapais
# ---------------------------------------
# Processing record 224 for the city: ponta do sol
# ---------------------------------------
# Processing record 225 for the city: codrington
# ---------------------------------------
# Processing record 226 for the city: tommot
# ---------------------------------------
# Processing record 227 for the city: namatanai
# ---------------------------------------
# Processing record 228 for the city: geraldton
# ---------------------------------------
# Processing record 229 for the city: tecolutla
# ---------------------------------------
# Processing record 230 for the city: mackay
# ---------------------------------------
# Processing record 231 for the city: east london
# ---------------------------------------
# Processing record 232 for the city: mae sai
# ---------------------------------------
# Processing record 233 for the city: christchurch
# ---------------------------------------
# Processing record 234 for the city: tammisaari
# ---------------------------------------
# Processing record 235 for the city: magnor
# ---------------------------------------
# Processing record 236 for the city: alice
# ---------------------------------------
# Processing record 237 for the city: hare bay
# ---------------------------------------
# Processing record 238 for the city: bali
# ---------------------------------------
# Processing record 239 for the city: carnarvon
# ---------------------------------------
# Processing record 240 for the city: alofi
# ---------------------------------------
# Processing record 241 for the city: albesti
# ---------------------------------------
# Processing record 242 for the city: garissa
# ---------------------------------------
# Processing record 243 for the city: monaragala
# ---------------------------------------
# Processing record 244 for the city: sept-iles
# ---------------------------------------
# Processing record 245 for the city: turayf
# ---------------------------------------
# Processing record 246 for the city: cabo san lucas
# ---------------------------------------
# Processing record 247 for the city: port augusta
# ---------------------------------------
# Processing record 248 for the city: wisconsin rapids
# ---------------------------------------
# Processing record 249 for the city: kavieng
# ---------------------------------------
# Processing record 250 for the city: santarem
# ---------------------------------------
# Processing record 251 for the city: puerto del rosario
# ---------------------------------------
# Processing record 252 for the city: makakilo city
# ---------------------------------------
# Processing record 253 for the city: adet
# ---------------------------------------
# Processing record 254 for the city: sibolga
# ---------------------------------------
# Processing record 255 for the city: gurupa
# ---------------------------------------
# Processing record 256 for the city: pringsewu
# ---------------------------------------
# Processing record 257 for the city: sao filipe
# ---------------------------------------
# Processing record 258 for the city: kuching
# ---------------------------------------
# Processing record 259 for the city: the valley
# ---------------------------------------
# Processing record 260 for the city: mayumba
# ---------------------------------------
# nizhneyansk not found in OpenWeather database.
# ---------------------------------------
# Processing record 262 for the city: meulaboh
# ---------------------------------------
# culipapa not found in OpenWeather database.
# ---------------------------------------
# Processing record 264 for the city: ekhabi
# ---------------------------------------
# Processing record 265 for the city: providencia
# ---------------------------------------
# Processing record 266 for the city: campos do jordao
# ---------------------------------------
# Processing record 267 for the city: porto seguro
# ---------------------------------------
# Processing record 268 for the city: manokwari
# ---------------------------------------
# Processing record 269 for the city: byron bay
# ---------------------------------------
# Processing record 270 for the city: abu samrah
# ---------------------------------------
# Processing record 271 for the city: heilbron
# ---------------------------------------
# Processing record 272 for the city: avera
# ---------------------------------------
# Processing record 273 for the city: solnechnyy
# ---------------------------------------
# Processing record 274 for the city: araouane
# ---------------------------------------
# Processing record 275 for the city: kashi
# ---------------------------------------
# Processing record 276 for the city: provideniya
# ---------------------------------------
# Processing record 277 for the city: teahupoo
# ---------------------------------------
# Processing record 278 for the city: aksarka
# ---------------------------------------
# Processing record 279 for the city: sisimiut
# ---------------------------------------
# Processing record 280 for the city: haukipudas
# ---------------------------------------
# Processing record 281 for the city: sambava
# ---------------------------------------
# Processing record 282 for the city: tuktoyaktuk
# ---------------------------------------
# Processing record 283 for the city: sola
# ---------------------------------------
# Processing record 284 for the city: mitu
# ---------------------------------------
# rawannawi not found in OpenWeather database.
# ---------------------------------------
# Processing record 286 for the city: cowra
# ---------------------------------------
# Processing record 287 for the city: gao
# ---------------------------------------
# Processing record 288 for the city: colquechaca
# ---------------------------------------
# Processing record 289 for the city: fallon
# ---------------------------------------
# Processing record 290 for the city: dawson creek
# ---------------------------------------
# Processing record 291 for the city: dolni bousov
# ---------------------------------------
# Processing record 292 for the city: bambous virieux
# ---------------------------------------
# bossembele not found in OpenWeather database.
# ---------------------------------------
# Processing record 294 for the city: banyo
# ---------------------------------------
# Processing record 295 for the city: fengxian
# ---------------------------------------
# Processing record 296 for the city: abramovka
# ---------------------------------------
# Processing record 297 for the city: halifax
# ---------------------------------------
# Processing record 298 for the city: fortuna
# ---------------------------------------
# Processing record 299 for the city: xuanhua
# ---------------------------------------
# Processing record 300 for the city: jiayuguan
# ---------------------------------------
# Processing record 301 for the city: leh
# ---------------------------------------
# Processing record 302 for the city: airai
# ---------------------------------------
# Processing record 303 for the city: new bern
# ---------------------------------------
# Processing record 304 for the city: victoria
# ---------------------------------------
# Processing record 305 for the city: ambilobe
# ---------------------------------------
# Processing record 306 for the city: pavlogradka
# ---------------------------------------
# Processing record 307 for the city: sokolo
# ---------------------------------------
# Processing record 308 for the city: saint anthony
# ---------------------------------------
# Processing record 309 for the city: hasaki
# ---------------------------------------
# Processing record 310 for the city: carauari
# ---------------------------------------
# Processing record 311 for the city: punta cardon
# ---------------------------------------
# Processing record 312 for the city: pisco
# ---------------------------------------
# Processing record 313 for the city: atar
# ---------------------------------------
# Processing record 314 for the city: augusto correa
# ---------------------------------------
# Processing record 315 for the city: la ronge
# ---------------------------------------
# Processing record 316 for the city: grand-santi
# ---------------------------------------
# Processing record 317 for the city: miramar
# ---------------------------------------
# Processing record 318 for the city: okhotsk
# ---------------------------------------
# Processing record 319 for the city: suez
# ---------------------------------------
# Processing record 320 for the city: chuy
# ---------------------------------------
# satitoa not found in OpenWeather database.
# ---------------------------------------
# Processing record 322 for the city: caravelas
# ---------------------------------------
# Processing record 323 for the city: malakal
# ---------------------------------------
# Processing record 324 for the city: ruiz
# ---------------------------------------
# tlapa not found in OpenWeather database.
# ---------------------------------------
# Processing record 326 for the city: bilma
# ---------------------------------------
# temaraia not found in OpenWeather database.
# ---------------------------------------
# Processing record 328 for the city: paciran
# ---------------------------------------
# Processing record 329 for the city: san quintin
# ---------------------------------------
# Processing record 330 for the city: karpathos
# ---------------------------------------
# Processing record 331 for the city: nha trang
# ---------------------------------------
# Processing record 332 for the city: usak
# ---------------------------------------
# Processing record 333 for the city: polson
# ---------------------------------------
# Processing record 334 for the city: varhaug
# ---------------------------------------
# Processing record 335 for the city: torbat-e jam
# ---------------------------------------
# Processing record 336 for the city: balakovo
# ---------------------------------------
# Processing record 337 for the city: havoysund
# ---------------------------------------
# Processing record 338 for the city: yulara
# ---------------------------------------
# Processing record 339 for the city: dicabisagan
# ---------------------------------------
# Processing record 340 for the city: formosa
# ---------------------------------------
# Processing record 341 for the city: kisangani
# ---------------------------------------
# Processing record 342 for the city: kysyl-syr
# ---------------------------------------
# Processing record 343 for the city: beringovskiy
# ---------------------------------------
# Processing record 344 for the city: saint marys
# ---------------------------------------
# Processing record 345 for the city: shahrud
# ---------------------------------------
# Processing record 346 for the city: moerai
# ---------------------------------------
# Processing record 347 for the city: bathsheba
# ---------------------------------------
# Processing record 348 for the city: agadir
# ---------------------------------------
# Processing record 349 for the city: ambanja
# ---------------------------------------
# Processing record 350 for the city: pacasmayo
# ---------------------------------------
# Processing record 351 for the city: qaqortoq
# ---------------------------------------
# Processing record 352 for the city: te anau
# ---------------------------------------
# Processing record 353 for the city: nemuro
# ---------------------------------------
# Processing record 354 for the city: velesta
# ---------------------------------------
# Processing record 355 for the city: nome
# ---------------------------------------
# Processing record 356 for the city: kushima
# ---------------------------------------
# Processing record 357 for the city: cascais
# ---------------------------------------
# Processing record 358 for the city: terrace bay
# ---------------------------------------
# Processing record 359 for the city: vila franca do campo
# ---------------------------------------
# Processing record 360 for the city: camacupa
# ---------------------------------------
# umzimvubu not found in OpenWeather database.
# ---------------------------------------
# Processing record 362 for the city: hobyo
# ---------------------------------------
# Processing record 363 for the city: faya
# ---------------------------------------
# Processing record 364 for the city: constitucion
# ---------------------------------------
# Processing record 365 for the city: shetpe
# ---------------------------------------
# Processing record 366 for the city: matay
# ---------------------------------------
# Processing record 367 for the city: mamou
# ---------------------------------------
# Processing record 368 for the city: ballina
# ---------------------------------------
# Processing record 369 for the city: lazaro cardenas
# ---------------------------------------
# taburi not found in OpenWeather database.
# ---------------------------------------
# Processing record 371 for the city: acu
# ---------------------------------------
# Processing record 372 for the city: elverum
# ---------------------------------------
# Processing record 373 for the city: northam
# ---------------------------------------
# Processing record 374 for the city: rudsar
# ---------------------------------------
# Processing record 375 for the city: punta alta
# ---------------------------------------
# Processing record 376 for the city: sirnak
# ---------------------------------------
# Processing record 377 for the city: khorramshahr
# ---------------------------------------
# Processing record 378 for the city: lompoc
# ---------------------------------------
# Processing record 379 for the city: mirabad
# ---------------------------------------
# Processing record 380 for the city: bairiki
# ---------------------------------------
# Processing record 381 for the city: kismayo
# ---------------------------------------
# Processing record 382 for the city: morant bay
# ---------------------------------------
# Processing record 383 for the city: dehui
# ---------------------------------------
# ulze not found in OpenWeather database.
# ---------------------------------------
# Processing record 385 for the city: nuuk
# ---------------------------------------
# Processing record 386 for the city: fort-shevchenko
# ---------------------------------------
# Processing record 387 for the city: santa fe
# ---------------------------------------
# grand river south east not found in OpenWeather database.
# ---------------------------------------
# Processing record 389 for the city: kahului
# ---------------------------------------
# Processing record 390 for the city: vikhorevka
# ---------------------------------------
# Processing record 391 for the city: port lincoln
# ---------------------------------------
# Processing record 392 for the city: evensk
# ---------------------------------------
# Processing record 393 for the city: narsaq
# ---------------------------------------
# Processing record 394 for the city: tabuk
# ---------------------------------------
# Processing record 395 for the city: turukhansk
# ---------------------------------------
# Processing record 396 for the city: ulladulla
# ---------------------------------------
# cagayan de tawi-tawi not found in OpenWeather database.
# ---------------------------------------
# Processing record 398 for the city: plettenberg bay
# ---------------------------------------
# Processing record 399 for the city: grindavik
# ---------------------------------------
# Processing record 400 for the city: laguna
# ---------------------------------------
# Processing record 401 for the city: galveston
# ---------------------------------------
# Processing record 402 for the city: bocaiuva
# ---------------------------------------
# Processing record 403 for the city: salinopolis
# ---------------------------------------
# Processing record 404 for the city: yuxia
# ---------------------------------------
# Processing record 405 for the city: labuhan
# ---------------------------------------
# Processing record 406 for the city: buy
# ---------------------------------------
# Processing record 407 for the city: cortez
# ---------------------------------------
# meyungs not found in OpenWeather database.
# ---------------------------------------
# Processing record 409 for the city: najran
# ---------------------------------------
# Processing record 410 for the city: cozumel
# ---------------------------------------
# Processing record 411 for the city: oranmore
# ---------------------------------------
# Processing record 412 for the city: olinda
# ---------------------------------------
# Processing record 413 for the city: vardo
# ---------------------------------------
# Processing record 414 for the city: batemans bay
# ---------------------------------------
# Processing record 415 for the city: santiago de cao
# ---------------------------------------
# Processing record 416 for the city: porlamar
# ---------------------------------------
# Processing record 417 for the city: buin
# ---------------------------------------
# Processing record 418 for the city: saint-pierre
# ---------------------------------------
# Processing record 419 for the city: tiznit
# ---------------------------------------
# Processing record 420 for the city: shimoda
# ---------------------------------------
# Processing record 421 for the city: gabriel leyva solano
# ---------------------------------------
# Processing record 422 for the city: boca do acre
# ---------------------------------------
# Processing record 423 for the city: arlit
# ---------------------------------------
# Processing record 424 for the city: nouadhibou
# ---------------------------------------
# Processing record 425 for the city: lishui
# ---------------------------------------
# Processing record 426 for the city: chestermere
# ---------------------------------------
# Processing record 427 for the city: portland
# ---------------------------------------
# Processing record 428 for the city: dzilam gonzalez
# ---------------------------------------
# Processing record 429 for the city: ahipara
# ---------------------------------------
# Processing record 430 for the city: sioux lookout
# ---------------------------------------
# Processing record 431 for the city: witu
# ---------------------------------------
# Processing record 432 for the city: marystown
# ---------------------------------------
# Processing record 433 for the city: caceres
# ---------------------------------------
# Processing record 434 for the city: nabire
# ---------------------------------------
# Processing record 435 for the city: tura
# ---------------------------------------
# Processing record 436 for the city: shaki
# ---------------------------------------
# Processing record 437 for the city: marawi
# ---------------------------------------
# Processing record 438 for the city: sidi ali
# ---------------------------------------
# Processing record 439 for the city: yatou
# ---------------------------------------
# Processing record 440 for the city: stabat
# ---------------------------------------
# Processing record 441 for the city: bogande
# ---------------------------------------
# Processing record 442 for the city: burnie
# ---------------------------------------
# Processing record 443 for the city: wanning
# ---------------------------------------
# Processing record 444 for the city: egvekinot
# ---------------------------------------
# Processing record 445 for the city: susaki
# ---------------------------------------
# Processing record 446 for the city: havelock
# ---------------------------------------
# Processing record 447 for the city: havre-saint-pierre
# ---------------------------------------
# Processing record 448 for the city: denpasar
# ---------------------------------------
# Processing record 449 for the city: lakhipur
# ---------------------------------------
# Processing record 450 for the city: lata
# ---------------------------------------
# andarab not found in OpenWeather database.
# ---------------------------------------
# Processing record 452 for the city: bijie
# ---------------------------------------
# Processing record 453 for the city: west helena
# ---------------------------------------
# Processing record 454 for the city: arrifes
# ---------------------------------------
# Processing record 455 for the city: qasigiannguit
# ---------------------------------------
# Processing record 456 for the city: honiara
# ---------------------------------------
# inderborskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 458 for the city: lasa
# ---------------------------------------
# Processing record 459 for the city: pemba
# ---------------------------------------
# Processing record 460 for the city: borovoy
# ---------------------------------------
# Processing record 461 for the city: chapada dos guimaraes
# ---------------------------------------
# Processing record 462 for the city: dingle
# ---------------------------------------
# Processing record 463 for the city: bermeo
# ---------------------------------------
# Processing record 464 for the city: minbu
# ---------------------------------------
# Processing record 465 for the city: bitung
# ---------------------------------------
# Processing record 466 for the city: anuchino
# ---------------------------------------
# Processing record 467 for the city: cap malheureux
# ---------------------------------------
# Processing record 468 for the city: morro bay
# ---------------------------------------
# Processing record 469 for the city: qena
# ---------------------------------------
# Processing record 470 for the city: westport
# ---------------------------------------
# Processing record 471 for the city: panguna
# ---------------------------------------
# Processing record 472 for the city: itarema
# ---------------------------------------
# Processing record 473 for the city: ferrol
# ---------------------------------------
# Processing record 474 for the city: upata
# ---------------------------------------
# Processing record 475 for the city: channel-port aux basques
# ---------------------------------------
# Processing record 476 for the city: broome
# ---------------------------------------
# Processing record 477 for the city: ust-maya
# ---------------------------------------
# Processing record 478 for the city: coquimbo
# ---------------------------------------
# Processing record 479 for the city: parral
# ---------------------------------------
# Processing record 480 for the city: high level
# ---------------------------------------
# Processing record 481 for the city: brae
# ---------------------------------------
# Processing record 482 for the city: scarborough
# ---------------------------------------
# Processing record 483 for the city: raudeberg
# ---------------------------------------
# Processing record 484 for the city: namibe
# ---------------------------------------
# Processing record 485 for the city: iskateley
# ---------------------------------------
# Processing record 486 for the city: ancud
# ---------------------------------------
# Processing record 487 for the city: buchanan
# ---------------------------------------
# Processing record 488 for the city: seymchan
# ---------------------------------------
# Processing record 489 for the city: pudozh
# ---------------------------------------
# Processing record 490 for the city: colwyn bay
# ---------------------------------------
# Processing record 491 for the city: huarmey
# ---------------------------------------
# Processing record 492 for the city: dunedin
# ---------------------------------------
# Processing record 493 for the city: wilmington island
# ---------------------------------------
# Processing record 494 for the city: makat
# ---------------------------------------
# Processing record 495 for the city: kirakira
# ---------------------------------------
# marcona not found in OpenWeather database.
# ---------------------------------------
# Processing record 497 for the city: simao
# ---------------------------------------
# Processing record 498 for the city: saryg-sep
# ---------------------------------------
# Processing record 499 for the city: novikovo
# ---------------------------------------
# Processing record 500 for the city: bodden town
# ---------------------------------------
# Processing record 501 for the city: palmer
# ---------------------------------------
# Processing record 502 for the city: padang
# ---------------------------------------
# Processing record 503 for the city: barra patuca
# ---------------------------------------
# Processing record 504 for the city: yagodnoye
# ---------------------------------------
# Processing record 505 for the city: verkhnyaya toyma
# ---------------------------------------
# Processing record 506 for the city: devonport
# ---------------------------------------
# Processing record 507 for the city: poddorye
# ---------------------------------------
# Processing record 508 for the city: shambu
# ---------------------------------------
# Processing record 509 for the city: kedrovyy
# ---------------------------------------
# Processing record 510 for the city: kalabo
# ---------------------------------------
# Processing record 511 for the city: oriximina
# ---------------------------------------
# Processing record 512 for the city: karratha
# ---------------------------------------
# Processing record 513 for the city: ulkan
# ---------------------------------------
# Processing record 514 for the city: matara
# ---------------------------------------
# santa eulalia del rio not found in OpenWeather database.
# ---------------------------------------
# Processing record 516 for the city: nijar
# ---------------------------------------
# Processing record 517 for the city: nouakchott
# ---------------------------------------
# Processing record 518 for the city: port keats
# ---------------------------------------
# Processing record 519 for the city: dzaoudzi
# ---------------------------------------
# Processing record 520 for the city: marsabit
# ---------------------------------------
# Processing record 521 for the city: praia da vitoria
# ---------------------------------------
# Processing record 522 for the city: sitka
# ---------------------------------------
# Processing record 523 for the city: aksay
# ---------------------------------------
# Processing record 524 for the city: tres arroyos
# ---------------------------------------
# Processing record 525 for the city: mayakonda
# ---------------------------------------
# Processing record 526 for the city: jasper
# ---------------------------------------
# Processing record 527 for the city: lagoa
# ---------------------------------------
# Processing record 528 for the city: marzuq
# ---------------------------------------
# Processing record 529 for the city: changtu
# ---------------------------------------
# Processing record 530 for the city: flinders
# ---------------------------------------
# Processing record 531 for the city: shimanovsk
# ---------------------------------------
# Processing record 532 for the city: mount gambier
# ---------------------------------------
# Processing record 533 for the city: kitimat
# ---------------------------------------
# Processing record 534 for the city: aloleng
# ---------------------------------------
# Processing record 535 for the city: manta
# ---------------------------------------
# Processing record 536 for the city: barentu
# ---------------------------------------
# Processing record 537 for the city: merauke
# ---------------------------------------
# Processing record 538 for the city: boende
# ---------------------------------------
# Processing record 539 for the city: nanakuli
# ---------------------------------------
# Processing record 540 for the city: sabang
# ---------------------------------------
# Processing record 541 for the city: hay river
# ---------------------------------------
# Processing record 542 for the city: yerofey pavlovich
# ---------------------------------------
# Processing record 543 for the city: college
# ---------------------------------------
# Processing record 544 for the city: samarai
# ---------------------------------------
# Processing record 545 for the city: tuatapere
# ---------------------------------------
# whitchurch-stouffville not found in OpenWeather database.
# ---------------------------------------
# Processing record 547 for the city: jumla
# ---------------------------------------
# Processing record 548 for the city: puerto escondido
# ---------------------------------------
# Processing record 549 for the city: belaya gora
# ---------------------------------------
# Processing record 550 for the city: felipe carrillo puerto
# ---------------------------------------
# Processing record 551 for the city: balkhash
# ---------------------------------------
# Processing record 552 for the city: oksfjord
# ---------------------------------------
# Processing record 553 for the city: tucurui
# ---------------------------------------
# Processing record 554 for the city: puerto quijarro
# ---------------------------------------
# Processing record 555 for the city: weligama
# ---------------------------------------
# Processing record 556 for the city: aasiaat
# ---------------------------------------
# jiddah not found in OpenWeather database.
# ---------------------------------------
# Processing record 558 for the city: manitouwadge
# ---------------------------------------
# Processing record 559 for the city: margate
# ---------------------------------------
# Processing record 560 for the city: dudinka
# ---------------------------------------
# Processing record 561 for the city: aksu
# ---------------------------------------
# Processing record 562 for the city: porteirinha
# ---------------------------------------
# Processing record 563 for the city: thinadhoo
# ---------------------------------------
# Processing record 564 for the city: srandakan
# ---------------------------------------
# barawe not found in OpenWeather database.
# ---------------------------------------
# Processing record 566 for the city: beidao
# ---------------------------------------
# Processing record 567 for the city: yar-sale
# ---------------------------------------
# Processing record 568 for the city: trujillo
# ---------------------------------------
# wahran not found in OpenWeather database.
# ---------------------------------------
# Processing record 570 for the city: walvis bay
# ---------------------------------------
# Processing record 571 for the city: nivala
# ---------------------------------------
# Processing record 572 for the city: san vicente de canete
# ---------------------------------------
# Processing record 573 for the city: concepcion
# ---------------------------------------
# Processing record 574 for the city: saint-augustin
# ---------------------------------------
# Processing record 575 for the city: san policarpo
# ---------------------------------------
# bolshoy tsaryn not found in OpenWeather database.
# ---------------------------------------
# tutla not found in OpenWeather database.
# ---------------------------------------
# halalo not found in OpenWeather database.
# ---------------------------------------
# Processing record 579 for the city: kosa
# ---------------------------------------
# Processing record 580 for the city: bima
# ---------------------------------------
# Processing record 581 for the city: bar harbor
# ---------------------------------------
# Processing record 582 for the city: jatai
# ---------------------------------------
# Processing record 583 for the city: alihe
# ---------------------------------------
# Processing record 584 for the city: poniatowa
# ---------------------------------------
# juifang not found in OpenWeather database.
# ---------------------------------------
# Processing record 586 for the city: newport
# ---------------------------------------
# Processing record 587 for the city: kapra
# ---------------------------------------
# Processing record 588 for the city: viedma
# ---------------------------------------
# Processing record 589 for the city: mulchen
# ---------------------------------------
# Processing record 590 for the city: eyl
# ---------------------------------------
# Processing record 591 for the city: kindu
# ---------------------------------------
# Processing record 592 for the city: ballaghaderreen
# ---------------------------------------
# Processing record 593 for the city: humberto de campos
# ---------------------------------------
# Processing record 594 for the city: huilong
# ---------------------------------------
# Processing record 595 for the city: camacha
# ---------------------------------------
# Processing record 596 for the city: muskegon
# ---------------------------------------
# Processing record 597 for the city: machali
# ---------------------------------------
# Processing record 598 for the city: tabou
# ---------------------------------------
# Processing record 599 for the city: fairbanks
# ---------------------------------------

# %%
len(city_name)
# Out:
# 552

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, temp, humidity, cloudiness, and wind speed.
weather_dict = {
    "City": city_name,
    "Latitude": lat,
    "Longitude": lng,
    "Temperature (F)": temp_max,
    "Humidity (%)": humidity,
    "Cloudiness (%)": clouds,
    "Wind Speed (mph)": wind_speed,
    "Date": date
    
    
}
weather_data = pd.DataFrame(weather_dict)

#Form https://www.programiz.com/python-programming/datetime/timestamp-datetime
now = datetime.now()

#Export weather data to csv.
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)

#Display df.
weather_data.head()
# Out:
#              City  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0  Saint-Philippe  -21.3585    55.7679            82.40            74
# 1      Gold Coast  -28.0000   153.4333            68.00            88
# 2          Atuona   -9.8000  -139.0333            78.28            76
# 3      Ambon City   -3.6954   128.1814            81.00            93
# 4         Ushuaia  -54.8000   -68.3000            50.00            71
#
#    Cloudiness (%)  Wind Speed (mph)        Date
# 0              20              2.30  1610988378
# 1              40             10.36  1610987597
# 2              72             19.62  1610988379
# 3              74              5.95  1610987832
# 4              75             11.50  1610988339

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hi_hum = weather_data.loc[weather_data['Humidity (%)'] > 100]
print(hi_hum)
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph), Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Temperature (F)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Maximum Temperature by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('world_temp_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that maximum daily temperature does go down as one moves further away from the equator (both North and South). Max. Temp. at latitudes further away from the equator are higher in the southern hemisphere than in the northern hemisphere currently. This latter observation is perhaps explained by the southern hemisphere being in summer, while the northern hemisphere is in winter currently. Due to the tilt of the Earth's axis, the southern hemisphere is facing to the sun and the northern hemisphere is facing away from the sun.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Humidity (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Humidity by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('world_hum_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no particular relationship between percent humidity and latitude. There is some clumping of points in the 80% to 100% humidity at latitudes above 40 degrees north, but no clear correlation to my eye.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Cloudiness (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Cloudiness by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('world_cloud_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no clear relationship between cloudiness and latitude. There is some clumping of data at 0%, 20%, 40%, ~75%, and 100%. This makes me think of human error in assigning the values.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Wind Speed (mph)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Wind Speed by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('world_wspeed_lat.png')
plt.show()

# %% [markdown]
# I see no clear relationship between wind speed and latitude on this plot.

# %% [markdown]
# ## Linear Regression

# %%
nh_data = weather_data.loc[weather_data['Latitude'] >=0]
sh_data = weather_data.loc[weather_data['Latitude'] <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('nh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is -0.84

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('sh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is 0.57

# %% [markdown]
# Analysis of Max. Temp. by latitude in both the southern and northern hemispheres show a strong correlation with the Max. Temp. getting higher as we get closer to the equator. In the southern hemisphere this manifests as a positve correlation (equator is on the right of the x-axis), in the northern hemisphere a negative correlation describes the same trend (equator is on the left of the x-axis).

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('nh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is 0.4

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('sh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is 0.28

# %% [markdown]
# In this analysis, humidity is increasing as we move further north from the equator and decreasing as we move further south from the equator. The Pearson correlation coefficient deonstrates a stronger correlation for the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('nh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is 0.27

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('sh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is 0.36

# %% [markdown]
# Analysis of cloudiness versus latitude shows a slight trend for cloudiness to increase in the southern hemisphere as we move towards the equator. In the northern hemisphere, cloudiness is increasing as we move away from the equator. In both the northern and the southern hemispheres there are clumps around 0% and near 100%, but no clear correlation to latitude is evident to my eye.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('nh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is 0.03

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('sh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is -0.22

# %% [markdown]
# These two plots show no correlation between wind speed and latitude in the northern hemisphere and a slight decrease in wind speed as we move towards the equator in the southern hemisphere. The correlation in the southern hemisphere appears weak.
