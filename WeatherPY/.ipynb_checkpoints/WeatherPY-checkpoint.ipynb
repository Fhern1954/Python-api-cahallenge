# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_name=[]
country_name=[]
lat = []
lng = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
date = []


# Loop through the list of cities and perform a request for data on each
count=0
print("Start API Call to OpenWeather Database ")
print("---------------------------------------")

for city in cities:
    try:
        count += 1
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        country_name.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        print(f"Processing record {count} for the city: {city}")
    
    except:
        #cities.remove(city)
        print(f"{city} not found in OpenWeather database.")
        pass

    print("---------------------------------------")
# Out:
# Start API Call to OpenWeather Database
# ---------------------------------------
# panjwin not found in OpenWeather database.
# ---------------------------------------
# Processing record 2 for the city: castrillon
# ---------------------------------------
# Processing record 3 for the city: eitorf
# ---------------------------------------
# Processing record 4 for the city: sola
# ---------------------------------------
# Processing record 5 for the city: longyearbyen
# ---------------------------------------
# Processing record 6 for the city: cape town
# ---------------------------------------
# Processing record 7 for the city: rikitea
# ---------------------------------------
# Processing record 8 for the city: guerrero negro
# ---------------------------------------
# Processing record 9 for the city: aklavik
# ---------------------------------------
# Processing record 10 for the city: bethel
# ---------------------------------------
# Processing record 11 for the city: east london
# ---------------------------------------
# Processing record 12 for the city: husavik
# ---------------------------------------
# Processing record 13 for the city: port blair
# ---------------------------------------
# Processing record 14 for the city: ust-kut
# ---------------------------------------
# Processing record 15 for the city: saldanha
# ---------------------------------------
# taolanaro not found in OpenWeather database.
# ---------------------------------------
# Processing record 17 for the city: rawson
# ---------------------------------------
# Processing record 18 for the city: ushuaia
# ---------------------------------------
# Processing record 19 for the city: clyde river
# ---------------------------------------
# Processing record 20 for the city: mayo
# ---------------------------------------
# Processing record 21 for the city: port moresby
# ---------------------------------------
# Processing record 22 for the city: haapiti
# ---------------------------------------
# Processing record 23 for the city: sokolo
# ---------------------------------------
# Processing record 24 for the city: hobart
# ---------------------------------------
# Processing record 25 for the city: atuona
# ---------------------------------------
# Processing record 26 for the city: hermanus
# ---------------------------------------
# samusu not found in OpenWeather database.
# ---------------------------------------
# Processing record 28 for the city: fez
# ---------------------------------------
# Processing record 29 for the city: hamadan
# ---------------------------------------
# illoqqortoormiut not found in OpenWeather database.
# ---------------------------------------
# grand river south east not found in OpenWeather database.
# ---------------------------------------
# Processing record 32 for the city: barrow
# ---------------------------------------
# Processing record 33 for the city: cherskiy
# ---------------------------------------
# Processing record 34 for the city: radaur
# ---------------------------------------
# Processing record 35 for the city: severo-kurilsk
# ---------------------------------------
# Processing record 36 for the city: katsuura
# ---------------------------------------
# okandja not found in OpenWeather database.
# ---------------------------------------
# Processing record 38 for the city: inirida
# ---------------------------------------
# nizhneyansk not found in OpenWeather database.
# ---------------------------------------
# Processing record 40 for the city: cidreira
# ---------------------------------------
# Processing record 41 for the city: pulivendla
# ---------------------------------------
# Processing record 42 for the city: ribeira grande
# ---------------------------------------
# Processing record 43 for the city: barcelos
# ---------------------------------------
# Processing record 44 for the city: santiago del estero
# ---------------------------------------
# Processing record 45 for the city: malampaka
# ---------------------------------------
# Processing record 46 for the city: tateyama
# ---------------------------------------
# Processing record 47 for the city: hilo
# ---------------------------------------
# kerki not found in OpenWeather database.
# ---------------------------------------
# barentsburg not found in OpenWeather database.
# ---------------------------------------
# Processing record 50 for the city: mount isa
# ---------------------------------------
# Processing record 51 for the city: punta arenas
# ---------------------------------------
# Processing record 52 for the city: dikson
# ---------------------------------------
# Processing record 53 for the city: la seyne-sur-mer
# ---------------------------------------
# Processing record 54 for the city: nikolskoye
# ---------------------------------------
# Processing record 55 for the city: saint pete beach
# ---------------------------------------
# Processing record 56 for the city: albany
# ---------------------------------------
# Processing record 57 for the city: tuatapere
# ---------------------------------------
# amderma not found in OpenWeather database.
# ---------------------------------------
# Processing record 59 for the city: baykit
# ---------------------------------------
# Processing record 60 for the city: bakchar
# ---------------------------------------
# Processing record 61 for the city: half moon bay
# ---------------------------------------
# bolungarvik not found in OpenWeather database.
# ---------------------------------------
# Processing record 63 for the city: xinzhi
# ---------------------------------------
# Processing record 64 for the city: port macquarie
# ---------------------------------------
# Processing record 65 for the city: osecina
# ---------------------------------------
# Processing record 66 for the city: miri
# ---------------------------------------
# Processing record 67 for the city: capitan bado
# ---------------------------------------
# Processing record 68 for the city: villa altagracia
# ---------------------------------------
# Processing record 69 for the city: berlevag
# ---------------------------------------
# Processing record 70 for the city: puerto escondido
# ---------------------------------------
# Processing record 71 for the city: bluff
# ---------------------------------------
# Processing record 72 for the city: thompson
# ---------------------------------------
# Processing record 73 for the city: rokytne
# ---------------------------------------
# Processing record 74 for the city: sirajganj
# ---------------------------------------
# Processing record 75 for the city: puerto ayora
# ---------------------------------------
# Processing record 76 for the city: paamiut
# ---------------------------------------
# Processing record 77 for the city: sao filipe
# ---------------------------------------
# Processing record 78 for the city: sitka
# ---------------------------------------
# Processing record 79 for the city: pisco
# ---------------------------------------
# Processing record 80 for the city: klyuchi
# ---------------------------------------
# Processing record 81 for the city: lavrentiya
# ---------------------------------------
# Processing record 82 for the city: mar del plata
# ---------------------------------------
# Processing record 83 for the city: pevek
# ---------------------------------------
# Processing record 84 for the city: hithadhoo
# ---------------------------------------
# Processing record 85 for the city: tanete
# ---------------------------------------
# Processing record 86 for the city: naica
# ---------------------------------------
# Processing record 87 for the city: ilulissat
# ---------------------------------------
# Processing record 88 for the city: upernavik
# ---------------------------------------
# Processing record 89 for the city: khatanga
# ---------------------------------------
# Processing record 90 for the city: dharmadam
# ---------------------------------------
# Processing record 91 for the city: luzhou
# ---------------------------------------
# Processing record 92 for the city: kieta
# ---------------------------------------
# Processing record 93 for the city: sao joao da barra
# ---------------------------------------
# Processing record 94 for the city: darnah
# ---------------------------------------
# Processing record 95 for the city: lebu
# ---------------------------------------
# Processing record 96 for the city: callaway
# ---------------------------------------
# sentyabrskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 98 for the city: piskavica
# ---------------------------------------
# Processing record 99 for the city: cabo san lucas
# ---------------------------------------
# Processing record 100 for the city: limbazi
# ---------------------------------------
# Processing record 101 for the city: touros
# ---------------------------------------
# Processing record 102 for the city: fairbanks
# ---------------------------------------
# Processing record 103 for the city: mataura
# ---------------------------------------
# Processing record 104 for the city: bengkulu
# ---------------------------------------
# Processing record 105 for the city: maxixe
# ---------------------------------------
# Processing record 106 for the city: brae
# ---------------------------------------
# Processing record 107 for the city: butaritari
# ---------------------------------------
# Processing record 108 for the city: rocha
# ---------------------------------------
# Processing record 109 for the city: honningsvag
# ---------------------------------------
# Processing record 110 for the city: jamestown
# ---------------------------------------
# Processing record 111 for the city: kavieng
# ---------------------------------------
# Processing record 112 for the city: huilong
# ---------------------------------------
# Processing record 113 for the city: hayden
# ---------------------------------------
# Processing record 114 for the city: busselton
# ---------------------------------------
# Processing record 115 for the city: picayune
# ---------------------------------------
# Processing record 116 for the city: sao bernardo
# ---------------------------------------
# Processing record 117 for the city: zhuhai
# ---------------------------------------
# Processing record 118 for the city: airai
# ---------------------------------------
# Processing record 119 for the city: qaanaaq
# ---------------------------------------
# Processing record 120 for the city: koroni
# ---------------------------------------
# Processing record 121 for the city: yulara
# ---------------------------------------
# Processing record 122 for the city: asau
# ---------------------------------------
# Processing record 123 for the city: provideniya
# ---------------------------------------
# Processing record 124 for the city: new norfolk
# ---------------------------------------
# Processing record 125 for the city: los llanos de aridane
# ---------------------------------------
# Processing record 126 for the city: urumqi
# ---------------------------------------
# Processing record 127 for the city: vaini
# ---------------------------------------
# Processing record 128 for the city: carnarvon
# ---------------------------------------
# Processing record 129 for the city: port lincoln
# ---------------------------------------
# Processing record 130 for the city: campbell river
# ---------------------------------------
# Processing record 131 for the city: oroville
# ---------------------------------------
# Processing record 132 for the city: khandyga
# ---------------------------------------
# Processing record 133 for the city: maheshwar
# ---------------------------------------
# Processing record 134 for the city: garowe
# ---------------------------------------
# Processing record 135 for the city: talakan
# ---------------------------------------
# Processing record 136 for the city: aden
# ---------------------------------------
# Processing record 137 for the city: avera
# ---------------------------------------
# tsihombe not found in OpenWeather database.
# ---------------------------------------
# Processing record 139 for the city: moindou
# ---------------------------------------
# Processing record 140 for the city: tandil
# ---------------------------------------
# Processing record 141 for the city: dicabisagan
# ---------------------------------------
# Processing record 142 for the city: port elizabeth
# ---------------------------------------
# Processing record 143 for the city: mount gambier
# ---------------------------------------
# Processing record 144 for the city: bredasdorp
# ---------------------------------------
# Processing record 145 for the city: bontang
# ---------------------------------------
# Processing record 146 for the city: port alfred
# ---------------------------------------
# Processing record 147 for the city: arraial do cabo
# ---------------------------------------
# Processing record 148 for the city: taraza
# ---------------------------------------
# Processing record 149 for the city: nantucket
# ---------------------------------------
# Processing record 150 for the city: nanganga
# ---------------------------------------
# Processing record 151 for the city: san quintin
# ---------------------------------------
# Processing record 152 for the city: chaman
# ---------------------------------------
# Processing record 153 for the city: sinnamary
# ---------------------------------------
# Processing record 154 for the city: koraput
# ---------------------------------------
# Processing record 155 for the city: castro
# ---------------------------------------
# Processing record 156 for the city: mandalgovi
# ---------------------------------------
# Processing record 157 for the city: bambous virieux
# ---------------------------------------
# Processing record 158 for the city: maceio
# ---------------------------------------
# Processing record 159 for the city: vostok
# ---------------------------------------
# Processing record 160 for the city: pozo colorado
# ---------------------------------------
# Processing record 161 for the city: chatra
# ---------------------------------------
# Processing record 162 for the city: grand gaube
# ---------------------------------------
# vaitupu not found in OpenWeather database.
# ---------------------------------------
# Processing record 164 for the city: buala
# ---------------------------------------
# Processing record 165 for the city: coquimbo
# ---------------------------------------
# Processing record 166 for the city: yellowknife
# ---------------------------------------
# saleaula not found in OpenWeather database.
# ---------------------------------------
# Processing record 168 for the city: kapaa
# ---------------------------------------
# umzimvubu not found in OpenWeather database.
# ---------------------------------------
# Processing record 170 for the city: ostrovnoy
# ---------------------------------------
# Processing record 171 for the city: langxiang
# ---------------------------------------
# Processing record 172 for the city: logstor
# ---------------------------------------
# Processing record 173 for the city: saint-philippe
# ---------------------------------------
# Processing record 174 for the city: karratha
# ---------------------------------------
# Processing record 175 for the city: soe
# ---------------------------------------
# Processing record 176 for the city: lao cai
# ---------------------------------------
# Processing record 177 for the city: iqaluit
# ---------------------------------------
# Processing record 178 for the city: sammamish
# ---------------------------------------
# Processing record 179 for the city: ponta do sol
# ---------------------------------------
# Processing record 180 for the city: tiksi
# ---------------------------------------
# Processing record 181 for the city: minab
# ---------------------------------------
# Processing record 182 for the city: talnakh
# ---------------------------------------
# Processing record 183 for the city: coihaique
# ---------------------------------------
# Processing record 184 for the city: akureyri
# ---------------------------------------
# Processing record 185 for the city: luganville
# ---------------------------------------
# Processing record 186 for the city: snezhnogorsk
# ---------------------------------------
# Processing record 187 for the city: malanje
# ---------------------------------------
# Processing record 188 for the city: dongsheng
# ---------------------------------------
# Processing record 189 for the city: danielskuil
# ---------------------------------------
# Processing record 190 for the city: dukat
# ---------------------------------------
# Processing record 191 for the city: hurghada
# ---------------------------------------
# Processing record 192 for the city: hasaki
# ---------------------------------------
# Processing record 193 for the city: kahului
# ---------------------------------------
# bargal not found in OpenWeather database.
# ---------------------------------------
# kuche not found in OpenWeather database.
# ---------------------------------------
# Processing record 196 for the city: mahebourg
# ---------------------------------------
# hunza not found in OpenWeather database.
# ---------------------------------------
# mys shmidta not found in OpenWeather database.
# ---------------------------------------
# Processing record 199 for the city: nome
# ---------------------------------------
# Processing record 200 for the city: maniwaki
# ---------------------------------------
# Processing record 201 for the city: sioux lookout
# ---------------------------------------
# Processing record 202 for the city: pasni
# ---------------------------------------
# Processing record 203 for the city: tarko-sale
# ---------------------------------------
# Processing record 204 for the city: baruun-urt
# ---------------------------------------
# Processing record 205 for the city: avarua
# ---------------------------------------
# Processing record 206 for the city: sechura
# ---------------------------------------
# Processing record 207 for the city: amahai
# ---------------------------------------
# Processing record 208 for the city: diamantino
# ---------------------------------------
# Processing record 209 for the city: alofi
# ---------------------------------------
# Processing record 210 for the city: soria
# ---------------------------------------
# Processing record 211 for the city: isangel
# ---------------------------------------
# Processing record 212 for the city: san cristobal
# ---------------------------------------
# Processing record 213 for the city: wajir
# ---------------------------------------
# Processing record 214 for the city: kaspiyskiy
# ---------------------------------------
# Processing record 215 for the city: zyryanka
# ---------------------------------------
# Processing record 216 for the city: carolina
# ---------------------------------------
# Processing record 217 for the city: kruisfontein
# ---------------------------------------
# Processing record 218 for the city: anadyr
# ---------------------------------------
# Processing record 219 for the city: loanda
# ---------------------------------------
# Processing record 220 for the city: itarema
# ---------------------------------------
# Processing record 221 for the city: cayenne
# ---------------------------------------
# Processing record 222 for the city: de-kastri
# ---------------------------------------
# Processing record 223 for the city: kodiak
# ---------------------------------------
# Processing record 224 for the city: kaitangata
# ---------------------------------------
# Processing record 225 for the city: zeya
# ---------------------------------------
# Processing record 226 for the city: poum
# ---------------------------------------
# Processing record 227 for the city: ust-nera
# ---------------------------------------
# Processing record 228 for the city: sisimiut
# ---------------------------------------
# Processing record 229 for the city: bemidji
# ---------------------------------------
# Processing record 230 for the city: rantauprapat
# ---------------------------------------
# Processing record 231 for the city: aviles
# ---------------------------------------
# belushya guba not found in OpenWeather database.
# ---------------------------------------
# Processing record 233 for the city: sumenep
# ---------------------------------------
# Processing record 234 for the city: zharkent
# ---------------------------------------
# Processing record 235 for the city: kenai
# ---------------------------------------
# fort saint john not found in OpenWeather database.
# ---------------------------------------
# Processing record 237 for the city: saskylakh
# ---------------------------------------
# Processing record 238 for the city: caravelas
# ---------------------------------------
# Processing record 239 for the city: medvezhyegorsk
# ---------------------------------------
# Processing record 240 for the city: ozernovskiy
# ---------------------------------------
# Processing record 241 for the city: tamahu
# ---------------------------------------
# Processing record 242 for the city: novoagansk
# ---------------------------------------
# Processing record 243 for the city: nanzhou
# ---------------------------------------
# Processing record 244 for the city: portland
# ---------------------------------------
# Processing record 245 for the city: dargaville
# ---------------------------------------
# Processing record 246 for the city: georgetown
# ---------------------------------------
# Processing record 247 for the city: tasiilaq
# ---------------------------------------
# Processing record 248 for the city: nelson bay
# ---------------------------------------
# Processing record 249 for the city: chokurdakh
# ---------------------------------------
# louisbourg not found in OpenWeather database.
# ---------------------------------------
# Processing record 251 for the city: tromso
# ---------------------------------------
# Processing record 252 for the city: paka
# ---------------------------------------
# Processing record 253 for the city: barra patuca
# ---------------------------------------
# pilao arcado not found in OpenWeather database.
# ---------------------------------------
# Processing record 255 for the city: mangan
# ---------------------------------------
# Processing record 256 for the city: batagay-alyta
# ---------------------------------------
# attawapiskat not found in OpenWeather database.
# ---------------------------------------
# Processing record 258 for the city: torbay
# ---------------------------------------
# Processing record 259 for the city: potenza picena
# ---------------------------------------
# Processing record 260 for the city: leningradskiy
# ---------------------------------------
# Processing record 261 for the city: bandarbeyla
# ---------------------------------------
# Processing record 262 for the city: shakawe
# ---------------------------------------
# Processing record 263 for the city: lazaro cardenas
# ---------------------------------------
# Processing record 264 for the city: fomboni
# ---------------------------------------
# Processing record 265 for the city: koulikoro
# ---------------------------------------
# Processing record 266 for the city: kumluca
# ---------------------------------------
# Processing record 267 for the city: samarai
# ---------------------------------------
# Processing record 268 for the city: gwadar
# ---------------------------------------
# Processing record 269 for the city: qingyuan
# ---------------------------------------
# Processing record 270 for the city: shaowu
# ---------------------------------------
# karkaralinsk not found in OpenWeather database.
# ---------------------------------------
# Processing record 272 for the city: mogadishu
# ---------------------------------------
# Processing record 273 for the city: vargem alta
# ---------------------------------------
# Processing record 274 for the city: rumonge
# ---------------------------------------
# Processing record 275 for the city: san policarpo
# ---------------------------------------
# Processing record 276 for the city: kampot
# ---------------------------------------
# Processing record 277 for the city: russell
# ---------------------------------------
# Processing record 278 for the city: sulangan
# ---------------------------------------
# Processing record 279 for the city: doctor juan leon mallorquin
# ---------------------------------------
# Processing record 280 for the city: hoganas
# ---------------------------------------
# Processing record 281 for the city: krasnoselkup
# ---------------------------------------
# Processing record 282 for the city: yumen
# ---------------------------------------
# Processing record 283 for the city: vagur
# ---------------------------------------
# Processing record 284 for the city: fort nelson
# ---------------------------------------
# Processing record 285 for the city: kudahuvadhoo
# ---------------------------------------
# Processing record 286 for the city: blackwater
# ---------------------------------------
# Processing record 287 for the city: ahipara
# ---------------------------------------
# Processing record 288 for the city: bilibino
# ---------------------------------------
# Processing record 289 for the city: pasighat
# ---------------------------------------
# Processing record 290 for the city: le marin
# ---------------------------------------
# Processing record 291 for the city: chapais
# ---------------------------------------
# Processing record 292 for the city: praia da vitoria
# ---------------------------------------
# Processing record 293 for the city: ancud
# ---------------------------------------
# Processing record 294 for the city: bilma
# ---------------------------------------
# Processing record 295 for the city: henties bay
# ---------------------------------------
# Processing record 296 for the city: klaksvik
# ---------------------------------------
# Processing record 297 for the city: alyangula
# ---------------------------------------
# Processing record 298 for the city: shenzhen
# ---------------------------------------
# Processing record 299 for the city: victoria
# ---------------------------------------
# Processing record 300 for the city: faya
# ---------------------------------------
# Processing record 301 for the city: moyale
# ---------------------------------------
# Processing record 302 for the city: te anau
# ---------------------------------------
# Processing record 303 for the city: miramar
# ---------------------------------------
# Processing record 304 for the city: honiara
# ---------------------------------------
# Processing record 305 for the city: eyl
# ---------------------------------------
# Processing record 306 for the city: parauna
# ---------------------------------------
# Processing record 307 for the city: qui nhon
# ---------------------------------------
# Processing record 308 for the city: huarmey
# ---------------------------------------
# Processing record 309 for the city: saint george
# ---------------------------------------
# Processing record 310 for the city: morehead
# ---------------------------------------
# Processing record 311 for the city: porto novo
# ---------------------------------------
# Processing record 312 for the city: new plymouth
# ---------------------------------------
# Processing record 313 for the city: kunya
# ---------------------------------------
# Processing record 314 for the city: tuktoyaktuk
# ---------------------------------------
# Processing record 315 for the city: saint anthony
# ---------------------------------------
# Processing record 316 for the city: shache
# ---------------------------------------
# Processing record 317 for the city: batagay
# ---------------------------------------
# Processing record 318 for the city: noyabrsk
# ---------------------------------------
# Processing record 319 for the city: norman wells
# ---------------------------------------
# Processing record 320 for the city: outlook
# ---------------------------------------
# Processing record 321 for the city: bati
# ---------------------------------------
# Processing record 322 for the city: marsa matruh
# ---------------------------------------
# Processing record 323 for the city: san patricio
# ---------------------------------------
# tabiauea not found in OpenWeather database.
# ---------------------------------------
# Processing record 325 for the city: beboto
# ---------------------------------------
# bacuit not found in OpenWeather database.
# ---------------------------------------
# Processing record 327 for the city: necochea
# ---------------------------------------
# Processing record 328 for the city: new glasgow
# ---------------------------------------
# Processing record 329 for the city: lokosovo
# ---------------------------------------
# Processing record 330 for the city: gat
# ---------------------------------------
# Processing record 331 for the city: wuwei
# ---------------------------------------
# Processing record 332 for the city: pangnirtung
# ---------------------------------------
# Processing record 333 for the city: sugag
# ---------------------------------------
# Processing record 334 for the city: charters towers
# ---------------------------------------
# Processing record 335 for the city: baturaja
# ---------------------------------------
# Processing record 336 for the city: faanui
# ---------------------------------------
# Processing record 337 for the city: flinders
# ---------------------------------------
# Processing record 338 for the city: sao domingos do maranhao
# ---------------------------------------
# Processing record 339 for the city: puro
# ---------------------------------------
# Processing record 340 for the city: yaan
# ---------------------------------------
# Processing record 341 for the city: moscow
# ---------------------------------------
# barawe not found in OpenWeather database.
# ---------------------------------------
# Processing record 343 for the city: kutum
# ---------------------------------------
# tumannyy not found in OpenWeather database.
# ---------------------------------------
# Processing record 345 for the city: najran
# ---------------------------------------
# Processing record 346 for the city: loandjili
# ---------------------------------------
# Processing record 347 for the city: tocopilla
# ---------------------------------------
# Processing record 348 for the city: cabedelo
# ---------------------------------------
# Processing record 349 for the city: labuhan
# ---------------------------------------
# Processing record 350 for the city: bestobe
# ---------------------------------------
# Processing record 351 for the city: port hardy
# ---------------------------------------
# Processing record 352 for the city: pyay
# ---------------------------------------
# Processing record 353 for the city: nova olinda do norte
# ---------------------------------------
# Processing record 354 for the city: nombre de dios
# ---------------------------------------
# Processing record 355 for the city: camacha
# ---------------------------------------
# hihifo not found in OpenWeather database.
# ---------------------------------------
# Processing record 357 for the city: kennett
# ---------------------------------------
# Processing record 358 for the city: oranjestad
# ---------------------------------------
# Processing record 359 for the city: itoman
# ---------------------------------------
# Processing record 360 for the city: hofn
# ---------------------------------------
# Processing record 361 for the city: hamilton
# ---------------------------------------
# Processing record 362 for the city: usinsk
# ---------------------------------------
# Processing record 363 for the city: hovd
# ---------------------------------------
# Processing record 364 for the city: bonavista
# ---------------------------------------
# Processing record 365 for the city: acapulco
# ---------------------------------------
# Processing record 366 for the city: sao paulo de olivenca
# ---------------------------------------
# Processing record 367 for the city: pochutla
# ---------------------------------------
# Processing record 368 for the city: westport
# ---------------------------------------
# Processing record 369 for the city: chulman
# ---------------------------------------
# Processing record 370 for the city: ngunguru
# ---------------------------------------
# Processing record 371 for the city: powell
# ---------------------------------------
# Processing record 372 for the city: along
# ---------------------------------------
# Processing record 373 for the city: codrington
# ---------------------------------------
# Processing record 374 for the city: makushino
# ---------------------------------------
# Processing record 375 for the city: bogale
# ---------------------------------------
# Processing record 376 for the city: acarau
# ---------------------------------------
# Processing record 377 for the city: champua
# ---------------------------------------
# Processing record 378 for the city: mitsamiouli
# ---------------------------------------
# Processing record 379 for the city: shumyachi
# ---------------------------------------
# zawiyat susah not found in OpenWeather database.
# ---------------------------------------
# Processing record 381 for the city: keti bandar
# ---------------------------------------
# Processing record 382 for the city: okato
# ---------------------------------------
# Processing record 383 for the city: dukstas
# ---------------------------------------
# Processing record 384 for the city: general roca
# ---------------------------------------
# Processing record 385 for the city: abay
# ---------------------------------------
# Processing record 386 for the city: saryg-sep
# ---------------------------------------
# marcona not found in OpenWeather database.
# ---------------------------------------
# Processing record 388 for the city: sistranda
# ---------------------------------------
# Processing record 389 for the city: naze
# ---------------------------------------
# Processing record 390 for the city: ambrolauri
# ---------------------------------------
# Processing record 391 for the city: bandundu
# ---------------------------------------
# Processing record 392 for the city: ahuatempan
# ---------------------------------------
# Processing record 393 for the city: egvekinot
# ---------------------------------------
# Processing record 394 for the city: ferme-neuve
# ---------------------------------------
# Processing record 395 for the city: bacolod
# ---------------------------------------
# Processing record 396 for the city: pinega
# ---------------------------------------
# Processing record 397 for the city: champerico
# ---------------------------------------
# Processing record 398 for the city: berezniki
# ---------------------------------------
# Processing record 399 for the city: novoselitskoye
# ---------------------------------------
# Processing record 400 for the city: kavaratti
# ---------------------------------------
# Processing record 401 for the city: dunedin
# ---------------------------------------
# Processing record 402 for the city: aykhal
# ---------------------------------------
# Processing record 403 for the city: santa helena
# ---------------------------------------
# Processing record 404 for the city: saint-pierre
# ---------------------------------------
# Processing record 405 for the city: oussouye
# ---------------------------------------
# Processing record 406 for the city: stornoway
# ---------------------------------------
# Processing record 407 for the city: savelugu
# ---------------------------------------
# Processing record 408 for the city: vila velha
# ---------------------------------------
# Processing record 409 for the city: keratea
# ---------------------------------------
# Processing record 410 for the city: kununurra
# ---------------------------------------
# Processing record 411 for the city: haines junction
# ---------------------------------------
# Processing record 412 for the city: suluq
# ---------------------------------------
# Processing record 413 for the city: itamarandiba
# ---------------------------------------
# Processing record 414 for the city: calama
# ---------------------------------------
# Processing record 415 for the city: mon
# ---------------------------------------
# Processing record 416 for the city: lompoc
# ---------------------------------------
# Processing record 417 for the city: devrek
# ---------------------------------------
# Processing record 418 for the city: banjar
# ---------------------------------------
# Processing record 419 for the city: marsabit
# ---------------------------------------
# Processing record 420 for the city: opotiki
# ---------------------------------------
# Processing record 421 for the city: kupino
# ---------------------------------------
# Processing record 422 for the city: broken hill
# ---------------------------------------
# Processing record 423 for the city: arlit
# ---------------------------------------
# Processing record 424 for the city: surt
# ---------------------------------------
# Processing record 425 for the city: andilamena
# ---------------------------------------
# Processing record 426 for the city: kokologo
# ---------------------------------------
# Processing record 427 for the city: mumford
# ---------------------------------------
# haibowan not found in OpenWeather database.
# ---------------------------------------
# jiddah not found in OpenWeather database.
# ---------------------------------------
# Processing record 430 for the city: alta floresta
# ---------------------------------------
# Processing record 431 for the city: tautira
# ---------------------------------------
# Processing record 432 for the city: atar
# ---------------------------------------
# Processing record 433 for the city: gillette
# ---------------------------------------
# Processing record 434 for the city: vagay
# ---------------------------------------
# Processing record 435 for the city: panguna
# ---------------------------------------
# Processing record 436 for the city: clovis
# ---------------------------------------
# Processing record 437 for the city: tomatlan
# ---------------------------------------
# Processing record 438 for the city: sabang
# ---------------------------------------
# Processing record 439 for the city: palencia
# ---------------------------------------
# Processing record 440 for the city: bayir
# ---------------------------------------
# Processing record 441 for the city: horqueta
# ---------------------------------------
# Processing record 442 for the city: geraldton
# ---------------------------------------
# Processing record 443 for the city: waipawa
# ---------------------------------------
# Processing record 444 for the city: sorland
# ---------------------------------------
# Processing record 445 for the city: atambua
# ---------------------------------------
# Processing record 446 for the city: kirakira
# ---------------------------------------
# Processing record 447 for the city: puerto baquerizo moreno
# ---------------------------------------
# Processing record 448 for the city: sao felix do xingu
# ---------------------------------------
# Processing record 449 for the city: lata
# ---------------------------------------
# Processing record 450 for the city: semey
# ---------------------------------------
# Processing record 451 for the city: belaya gora
# ---------------------------------------
# Processing record 452 for the city: polovinnoye
# ---------------------------------------
# Processing record 453 for the city: souillac
# ---------------------------------------
# Processing record 454 for the city: moussoro
# ---------------------------------------
# Processing record 455 for the city: mehamn
# ---------------------------------------
# Processing record 456 for the city: havre-saint-pierre
# ---------------------------------------
# Processing record 457 for the city: magadi
# ---------------------------------------
# Processing record 458 for the city: leh
# ---------------------------------------
# Processing record 459 for the city: margate
# ---------------------------------------
# Processing record 460 for the city: esperance
# ---------------------------------------
# Processing record 461 for the city: pechenga
# ---------------------------------------
# Processing record 462 for the city: san ramon
# ---------------------------------------
# Processing record 463 for the city: semnan
# ---------------------------------------
# Processing record 464 for the city: nanortalik
# ---------------------------------------
# Processing record 465 for the city: waingapu
# ---------------------------------------
# Processing record 466 for the city: tuy hoa
# ---------------------------------------
# Processing record 467 for the city: loiza
# ---------------------------------------
# Processing record 468 for the city: myanaung
# ---------------------------------------
# Processing record 469 for the city: parvatsar
# ---------------------------------------
# Processing record 470 for the city: walvis bay
# ---------------------------------------
# Processing record 471 for the city: vredendal
# ---------------------------------------
# Processing record 472 for the city: fortuna
# ---------------------------------------
# Processing record 473 for the city: marawi
# ---------------------------------------
# Processing record 474 for the city: sambava
# ---------------------------------------
# Processing record 475 for the city: abbeville
# ---------------------------------------
# Processing record 476 for the city: biak
# ---------------------------------------
# Processing record 477 for the city: vila
# ---------------------------------------
# Processing record 478 for the city: aksarka
# ---------------------------------------
# cambyreta not found in OpenWeather database.
# ---------------------------------------
# Processing record 480 for the city: tevaitoa
# ---------------------------------------
# Processing record 481 for the city: namibe
# ---------------------------------------
# Processing record 482 for the city: mnogovershinnyy
# ---------------------------------------
# Processing record 483 for the city: jumla
# ---------------------------------------
# Processing record 484 for the city: rio verde de mato grosso
# ---------------------------------------
# Processing record 485 for the city: leeton
# ---------------------------------------
# Processing record 486 for the city: tire
# ---------------------------------------
# Processing record 487 for the city: gravdal
# ---------------------------------------
# Processing record 488 for the city: coihueco
# ---------------------------------------
# Processing record 489 for the city: wexford
# ---------------------------------------
# Processing record 490 for the city: zaragoza
# ---------------------------------------
# Processing record 491 for the city: tecoanapa
# ---------------------------------------
# Processing record 492 for the city: gushikawa
# ---------------------------------------
# Processing record 493 for the city: taiobeiras
# ---------------------------------------
# Processing record 494 for the city: carutapera
# ---------------------------------------
# Processing record 495 for the city: solnechnyy
# ---------------------------------------
# Processing record 496 for the city: lagoa
# ---------------------------------------
# Processing record 497 for the city: porto belo
# ---------------------------------------
# Processing record 498 for the city: batticaloa
# ---------------------------------------
# Processing record 499 for the city: salalah
# ---------------------------------------
# Processing record 500 for the city: acari
# ---------------------------------------
# Processing record 501 for the city: conceicao do araguaia
# ---------------------------------------
# Processing record 502 for the city: burnie
# ---------------------------------------
# Processing record 503 for the city: menzelinsk
# ---------------------------------------
# Processing record 504 for the city: roma
# ---------------------------------------
# Processing record 505 for the city: taoudenni
# ---------------------------------------
# dzhusaly not found in OpenWeather database.
# ---------------------------------------
# lushunkou not found in OpenWeather database.
# ---------------------------------------
# Processing record 508 for the city: yuanping
# ---------------------------------------
# mergui not found in OpenWeather database.
# ---------------------------------------
# Processing record 510 for the city: kuusamo
# ---------------------------------------
# Processing record 511 for the city: narsaq
# ---------------------------------------
# Processing record 512 for the city: porto torres
# ---------------------------------------
# Processing record 513 for the city: watsa
# ---------------------------------------
# Processing record 514 for the city: domoni
# ---------------------------------------
# Processing record 515 for the city: muana
# ---------------------------------------
# Processing record 516 for the city: raisen
# ---------------------------------------
# Processing record 517 for the city: homer
# ---------------------------------------
# Processing record 518 for the city: carmaux
# ---------------------------------------
# Processing record 519 for the city: chitral
# ---------------------------------------
# Processing record 520 for the city: port hedland
# ---------------------------------------
# Processing record 521 for the city: yenagoa
# ---------------------------------------
# Processing record 522 for the city: northam
# ---------------------------------------
# Processing record 523 for the city: palana
# ---------------------------------------
# mahaicony not found in OpenWeather database.
# ---------------------------------------
# Processing record 525 for the city: arman
# ---------------------------------------
# Processing record 526 for the city: suntar
# ---------------------------------------
# Processing record 527 for the city: nanakuli
# ---------------------------------------
# Processing record 528 for the city: manjeri
# ---------------------------------------
# Processing record 529 for the city: turayf
# ---------------------------------------
# Processing record 530 for the city: qaqortoq
# ---------------------------------------
# Processing record 531 for the city: mezen
# ---------------------------------------
# Processing record 532 for the city: lorengau
# ---------------------------------------
# Processing record 533 for the city: port keats
# ---------------------------------------
# Processing record 534 for the city: batemans bay
# ---------------------------------------
# Processing record 535 for the city: dalby
# ---------------------------------------
# Processing record 536 for the city: evensk
# ---------------------------------------
# Processing record 537 for the city: irbeyskoye
# ---------------------------------------
# Processing record 538 for the city: mus
# ---------------------------------------
# Processing record 539 for the city: jieshi
# ---------------------------------------
# Processing record 540 for the city: mabaruma
# ---------------------------------------
# Processing record 541 for the city: nouadhibou
# ---------------------------------------
# Processing record 542 for the city: kamaishi
# ---------------------------------------
# Processing record 543 for the city: chuy
# ---------------------------------------
# Processing record 544 for the city: nizwa
# ---------------------------------------
# Processing record 545 for the city: dingle
# ---------------------------------------
# Processing record 546 for the city: tual
# ---------------------------------------
# Processing record 547 for the city: thinadhoo
# ---------------------------------------
# Processing record 548 for the city: port-gentil
# ---------------------------------------
# Processing record 549 for the city: houma
# ---------------------------------------
# Processing record 550 for the city: khandbari
# ---------------------------------------
# Processing record 551 for the city: kanye
# ---------------------------------------
# Processing record 552 for the city: makakilo city
# ---------------------------------------
# Processing record 553 for the city: tres arroyos
# ---------------------------------------
# Processing record 554 for the city: nalut
# ---------------------------------------
# sorvag not found in OpenWeather database.
# ---------------------------------------
# Processing record 556 for the city: manadhoo
# ---------------------------------------
# Processing record 557 for the city: chiesanuova
# ---------------------------------------
# Processing record 558 for the city: san luis
# ---------------------------------------
# Processing record 559 for the city: hami
# ---------------------------------------
# Processing record 560 for the city: anloga
# ---------------------------------------
# Processing record 561 for the city: hobyo
# ---------------------------------------
# Processing record 562 for the city: tura
# ---------------------------------------
# Processing record 563 for the city: tongliao
# ---------------------------------------
# Processing record 564 for the city: jacksonville beach
# ---------------------------------------
# Processing record 565 for the city: vicuna
# ---------------------------------------
# Processing record 566 for the city: nusaybin
# ---------------------------------------
# Processing record 567 for the city: ottawa
# ---------------------------------------
# Processing record 568 for the city: nata
# ---------------------------------------
# Processing record 569 for the city: yerbogachen
# ---------------------------------------
# kuhestan not found in OpenWeather database.
# ---------------------------------------
# karauzyak not found in OpenWeather database.
# ---------------------------------------
# Processing record 572 for the city: tsiroanomandidy
# ---------------------------------------
# Processing record 573 for the city: skawina
# ---------------------------------------
# Processing record 574 for the city: tukan
# ---------------------------------------
# Processing record 575 for the city: cervo
# ---------------------------------------
# Processing record 576 for the city: boddam
# ---------------------------------------
# Processing record 577 for the city: wagar
# ---------------------------------------
# Processing record 578 for the city: plettenberg bay
# ---------------------------------------
# Processing record 579 for the city: ocos
# ---------------------------------------
# Processing record 580 for the city: norwich
# ---------------------------------------
# Processing record 581 for the city: reconquista
# ---------------------------------------
# kamenskoye not found in OpenWeather database.
# ---------------------------------------
# Processing record 583 for the city: ola
# ---------------------------------------
# crab hill not found in OpenWeather database.
# ---------------------------------------
# Processing record 585 for the city: bahia blanca
# ---------------------------------------
# Processing record 586 for the city: axim
# ---------------------------------------
# Processing record 587 for the city: takoradi
# ---------------------------------------
# Processing record 588 for the city: durango
# ---------------------------------------
# Processing record 589 for the city: vanersborg
# ---------------------------------------
# Processing record 590 for the city: ostersund
# ---------------------------------------
# Processing record 591 for the city: mecca
# ---------------------------------------
# Processing record 592 for the city: umm lajj
# ---------------------------------------
# Processing record 593 for the city: taltal
# ---------------------------------------
# Processing record 594 for the city: zhangye
# ---------------------------------------
# Processing record 595 for the city: gizo
# ---------------------------------------
# Processing record 596 for the city: jibuti
# ---------------------------------------
# Processing record 597 for the city: tashtyp
# ---------------------------------------
# Processing record 598 for the city: mantua
# ---------------------------------------
# maloyaz not found in OpenWeather database.
# ---------------------------------------
# Processing record 600 for the city: quatre cocos
# ---------------------------------------
# Processing record 601 for the city: lodja
# ---------------------------------------
# Processing record 602 for the city: xam nua
# ---------------------------------------
# meyungs not found in OpenWeather database.
# ---------------------------------------
# Processing record 604 for the city: znamenskoye
# ---------------------------------------
# Processing record 605 for the city: teguise
# ---------------------------------------
# Processing record 606 for the city: catia la mar
# ---------------------------------------
# Processing record 607 for the city: vila franca do campo
# ---------------------------------------

# %%
len(city_name)
# Out:
# 560

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, temp, humidity, cloudiness, and wind speed.
weather_dict = {
    "City": city_name,
    "Country": country_name,
    "Latitude": lat,
    "Longitude": lng,
    "Temperature (F)": temp_max,
    "Humidity (%)": humidity,
    "Cloudiness (%)": clouds,
    "Wind Speed (mph)": wind_speed,
    "Date": date
    
    
}
weather_data = pd.DataFrame(weather_dict)

#Form https://www.programiz.com/python-programming/datetime/timestamp-datetime
now = datetime.now()

#Export weather data to csv.
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)

#Display df.
weather_data.head()
# Out:
#            City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0    Castrillón      ES   43.3979    -6.7922             51.8            54
# 1        Eitorf      DE   50.7667     7.4500             39.2            81
# 2          Sola      VU  -13.8833   167.5500             83.1            72
# 3  Longyearbyen      SJ   78.2186    15.6401             21.2            63
# 4     Cape Town      ZA  -33.9258    18.4232             68.0            68
#
#    Cloudiness (%)  Wind Speed (mph)        Date
# 0               0              2.30  1611098829
# 1               0              8.05  1611098829
# 2              82              5.21  1611098829
# 3              75             14.97  1611098829
# 4              20             18.41  1611098555

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hi_hum = weather_data.loc[weather_data['Humidity (%)'] > 100]
print(hi_hum)
# Out:
# Empty DataFrame
# Columns: [City, Country, Latitude, Longitude, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph), Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Temperature (F)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Maximum Temperature by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('world_temp_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that maximum daily temperature does go down as one moves further away from the equator (both North and South). Max. Temp. at latitudes further away from the equator are higher in the southern hemisphere than in the northern hemisphere currently. This latter observation is perhaps explained by the southern hemisphere being in summer, while the northern hemisphere is in winter currently. Due to the tilt of the Earth's axis, the southern hemisphere is facing to the sun and the northern hemisphere is facing away from the sun.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Humidity (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Humidity by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('world_hum_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no particular relationship between percent humidity and latitude. There is some clumping of points in the 80% to 100% humidity at latitudes above 40 degrees north, but no clear correlation to my eye.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Cloudiness (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Cloudiness by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('world_cloud_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no clear relationship between cloudiness and latitude. There is some clumping of data at 0%, 20%, 40%, ~75%, and 100%. This makes me think of human error in assigning the values.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Wind Speed (mph)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Wind Speed by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('world_wspeed_lat.png')
plt.show()

# %% [markdown]
# I see no clear relationship between wind speed and latitude on this plot.

# %% [markdown]
# ## Linear Regression

# %%
nh_data = weather_data.loc[weather_data['Latitude'] >=0]
sh_data = weather_data.loc[weather_data['Latitude'] <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
#plt.savefig('nh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is -0.84

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
#plt.savefig('sh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is 0.53

# %% [markdown]
# Analysis of Max. Temp. by latitude in both the southern and northern hemispheres show a strong correlation with the Max. Temp. getting higher as we get closer to the equator. In the southern hemisphere this manifests as a positve correlation (equator is on the right of the x-axis), in the northern hemisphere a negative correlation describes the same trend (equator is on the left of the x-axis).

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
#plt.savefig('nh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is 0.3

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
#plt.savefig('sh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is 0.46

# %% [markdown]
# In this analysis, humidity is increasing as we move further north from the equator and decreasing as we move further south from the equator. The Pearson correlation coefficient deonstrates a stronger correlation for the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
#plt.savefig('nh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is 0.24

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
#plt.savefig('sh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is 0.35

# %% [markdown]
# Analysis of cloudiness versus latitude shows a slight trend for cloudiness to increase in the southern hemisphere as we move towards the equator. In the northern hemisphere, cloudiness is increasing as we move away from the equator. In both the northern and the southern hemispheres there are clumps around 0% and near 100%, but no clear correlation to latitude is evident to my eye.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
#plt.savefig('nh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is 0.02

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
#plt.savefig('sh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is -0.27

# %% [markdown]
# These two plots show no correlation between wind speed and latitude in the northern hemisphere and a slight decrease in wind speed as we move towards the equator in the southern hemisphere. The correlation in the southern hemisphere appears weak.
