# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_name=[]
lat = []
temp_max = []
humidity = []
clouds = []
wind_speed = []



# Loop through the list of cities and perform a request for data on each
count=0
print("Start API Call to OpenWeather Database ")
print("---------------------------------------")

for city in cities:
    try:
        count += 1
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print(f"Processing record {count} for the city: {city}")
    
    except:
        #cities.remove(city)
        print(f"{city} not found in OpenWeather database.")
        pass

    print("---------------------------------------")
# Out:
# Start API Call to OpenWeather Database
# ---------------------------------------
# Processing record 1 for the city: busselton
# ---------------------------------------
# Processing record 2 for the city: albany
# ---------------------------------------
# Processing record 3 for the city: mount gambier
# ---------------------------------------
# Processing record 4 for the city: hithadhoo
# ---------------------------------------
# Processing record 5 for the city: ilulissat
# ---------------------------------------
# Processing record 6 for the city: arraial do cabo
# ---------------------------------------
# Processing record 7 for the city: urubicha
# ---------------------------------------
# Processing record 8 for the city: halifax
# ---------------------------------------
# Processing record 9 for the city: pochutla
# ---------------------------------------
# Processing record 10 for the city: puerto ayora
# ---------------------------------------
# Processing record 11 for the city: saint-philippe
# ---------------------------------------
# Processing record 12 for the city: mandera
# ---------------------------------------
# Processing record 13 for the city: merrill
# ---------------------------------------
# Processing record 14 for the city: kodinar
# ---------------------------------------
# Processing record 15 for the city: bonthe
# ---------------------------------------
# Processing record 16 for the city: ulaangom
# ---------------------------------------
# Processing record 17 for the city: sitka
# ---------------------------------------
# Processing record 18 for the city: muyezerskiy
# ---------------------------------------
# Processing record 19 for the city: provideniya
# ---------------------------------------
# illoqqortoormiut not found in OpenWeather database.
# ---------------------------------------
# Processing record 21 for the city: ushuaia
# ---------------------------------------
# Processing record 22 for the city: port alfred
# ---------------------------------------
# Processing record 23 for the city: arman
# ---------------------------------------
# Processing record 24 for the city: gat
# ---------------------------------------
# Processing record 25 for the city: tuktoyaktuk
# ---------------------------------------
# Processing record 26 for the city: carnarvon
# ---------------------------------------
# Processing record 27 for the city: barrow
# ---------------------------------------
# Processing record 28 for the city: amahai
# ---------------------------------------
# Processing record 29 for the city: boda
# ---------------------------------------
# Processing record 30 for the city: chinsali
# ---------------------------------------
# Processing record 31 for the city: fairbanks
# ---------------------------------------
# Processing record 32 for the city: oranjemund
# ---------------------------------------
# Processing record 33 for the city: vardo
# ---------------------------------------
# Processing record 34 for the city: kapaa
# ---------------------------------------
# Processing record 35 for the city: bluff
# ---------------------------------------
# Processing record 36 for the city: mataura
# ---------------------------------------
# Processing record 37 for the city: bambous virieux
# ---------------------------------------
# Processing record 38 for the city: bengkulu
# ---------------------------------------
# Processing record 39 for the city: hobyo
# ---------------------------------------
# Processing record 40 for the city: lebu
# ---------------------------------------
# Processing record 41 for the city: rikitea
# ---------------------------------------
# khormuj not found in OpenWeather database.
# ---------------------------------------
# Processing record 43 for the city: safford
# ---------------------------------------
# Processing record 44 for the city: isla
# ---------------------------------------
# barentsburg not found in OpenWeather database.
# ---------------------------------------
# Processing record 46 for the city: hilo
# ---------------------------------------
# Processing record 47 for the city: newcastle
# ---------------------------------------
# Processing record 48 for the city: new norfolk
# ---------------------------------------
# Processing record 49 for the city: kuruman
# ---------------------------------------
# nizhneyansk not found in OpenWeather database.
# ---------------------------------------
# Processing record 51 for the city: bredasdorp
# ---------------------------------------
# Processing record 52 for the city: kushima
# ---------------------------------------
# Processing record 53 for the city: cape town
# ---------------------------------------
# Processing record 54 for the city: novopokrovka
# ---------------------------------------
# Processing record 55 for the city: matagami
# ---------------------------------------
# Processing record 56 for the city: vao
# ---------------------------------------
# Processing record 57 for the city: christchurch
# ---------------------------------------
# Processing record 58 for the city: avarua
# ---------------------------------------
# Processing record 59 for the city: coquimbo
# ---------------------------------------
# Processing record 60 for the city: punta arenas
# ---------------------------------------
# Processing record 61 for the city: knysna
# ---------------------------------------
# Processing record 62 for the city: hasaki
# ---------------------------------------
# Processing record 63 for the city: yellowknife
# ---------------------------------------
# Processing record 64 for the city: qaanaaq
# ---------------------------------------
# Processing record 65 for the city: fairfield
# ---------------------------------------
# Processing record 66 for the city: nancha
# ---------------------------------------
# Processing record 67 for the city: port elizabeth
# ---------------------------------------
# Processing record 68 for the city: butaritari
# ---------------------------------------
# Processing record 69 for the city: nikolskoye
# ---------------------------------------
# Processing record 70 for the city: zhezkazgan
# ---------------------------------------
# Processing record 71 for the city: airai
# ---------------------------------------
# Processing record 72 for the city: cabedelo
# ---------------------------------------
# Processing record 73 for the city: ponta do sol
# ---------------------------------------
# Processing record 74 for the city: cap-aux-meules
# ---------------------------------------
# Processing record 75 for the city: codrington
# ---------------------------------------
# Processing record 76 for the city: aklavik
# ---------------------------------------
# Processing record 77 for the city: saldanha
# ---------------------------------------
# Processing record 78 for the city: missoula
# ---------------------------------------
# Processing record 79 for the city: pangkalanbuun
# ---------------------------------------
# Processing record 80 for the city: torbay
# ---------------------------------------
# sumbawa not found in OpenWeather database.
# ---------------------------------------
# Processing record 82 for the city: cacoal
# ---------------------------------------
# Processing record 83 for the city: aracruz
# ---------------------------------------
# Processing record 84 for the city: benghazi
# ---------------------------------------
# Processing record 85 for the city: jamestown
# ---------------------------------------
# Processing record 86 for the city: los llanos de aridane
# ---------------------------------------
# safwah not found in OpenWeather database.
# ---------------------------------------
# Processing record 88 for the city: vagur
# ---------------------------------------
# Processing record 89 for the city: celestun
# ---------------------------------------
# Processing record 90 for the city: kavaratti
# ---------------------------------------
# Processing record 91 for the city: antsohihy
# ---------------------------------------
# Processing record 92 for the city: burns lake
# ---------------------------------------
# Processing record 93 for the city: bombay
# ---------------------------------------
# Processing record 94 for the city: atuona
# ---------------------------------------
# Processing record 95 for the city: fort nelson
# ---------------------------------------
# Processing record 96 for the city: klaksvik
# ---------------------------------------
# Processing record 97 for the city: sao gabriel da cachoeira
# ---------------------------------------
# Processing record 98 for the city: thompson
# ---------------------------------------
# Processing record 99 for the city: pahrump
# ---------------------------------------
# Processing record 100 for the city: pacific grove
# ---------------------------------------
# Processing record 101 for the city: guilin
# ---------------------------------------
# tsihombe not found in OpenWeather database.
# ---------------------------------------
# Processing record 103 for the city: saskylakh
# ---------------------------------------
# umzimvubu not found in OpenWeather database.
# ---------------------------------------
# Processing record 105 for the city: uige
# ---------------------------------------
# Processing record 106 for the city: dikson
# ---------------------------------------
# Processing record 107 for the city: gravdal
# ---------------------------------------
# Processing record 108 for the city: gazanjyk
# ---------------------------------------
# Processing record 109 for the city: magadan
# ---------------------------------------
# Processing record 110 for the city: georgetown
# ---------------------------------------
# Processing record 111 for the city: makakilo city
# ---------------------------------------
# Processing record 112 for the city: mahebourg
# ---------------------------------------
# taolanaro not found in OpenWeather database.
# ---------------------------------------
# Processing record 114 for the city: vila velha
# ---------------------------------------
# Processing record 115 for the city: beringovskiy
# ---------------------------------------
# Processing record 116 for the city: mar del plata
# ---------------------------------------
# Processing record 117 for the city: sawtell
# ---------------------------------------
# amderma not found in OpenWeather database.
# ---------------------------------------
# Processing record 119 for the city: autazes
# ---------------------------------------
# Processing record 120 for the city: kodiak
# ---------------------------------------
# Processing record 121 for the city: coihaique
# ---------------------------------------
# aflu not found in OpenWeather database.
# ---------------------------------------
# Processing record 123 for the city: tuatapere
# ---------------------------------------
# Processing record 124 for the city: key west
# ---------------------------------------
# Processing record 125 for the city: cayenne
# ---------------------------------------
# Processing record 126 for the city: kasugai
# ---------------------------------------
# Processing record 127 for the city: kavieng
# ---------------------------------------
# Processing record 128 for the city: yarim
# ---------------------------------------
# Processing record 129 for the city: batemans bay
# ---------------------------------------
# Processing record 130 for the city: upernavik
# ---------------------------------------
# Processing record 131 for the city: iqaluit
# ---------------------------------------
# Processing record 132 for the city: fare
# ---------------------------------------
# Processing record 133 for the city: shelburne
# ---------------------------------------
# Processing record 134 for the city: sao joao da barra
# ---------------------------------------
# Processing record 135 for the city: sao filipe
# ---------------------------------------
# Processing record 136 for the city: katsuura
# ---------------------------------------
# Processing record 137 for the city: hambantota
# ---------------------------------------
# nguiu not found in OpenWeather database.
# ---------------------------------------
# Processing record 139 for the city: show low
# ---------------------------------------
# Processing record 140 for the city: yining
# ---------------------------------------
# cheuskiny not found in OpenWeather database.
# ---------------------------------------
# Processing record 142 for the city: da nang
# ---------------------------------------
# Processing record 143 for the city: koroni
# ---------------------------------------
# Processing record 144 for the city: geraldton
# ---------------------------------------
# Processing record 145 for the city: soderhamn
# ---------------------------------------
# Processing record 146 for the city: hofn
# ---------------------------------------
# Processing record 147 for the city: half moon bay
# ---------------------------------------
# Processing record 148 for the city: enid
# ---------------------------------------
# sentyabrskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 150 for the city: kaspiyskiy
# ---------------------------------------
# Processing record 151 for the city: bathsheba
# ---------------------------------------
# Processing record 152 for the city: hualmay
# ---------------------------------------
# Processing record 153 for the city: kieta
# ---------------------------------------
# burica not found in OpenWeather database.
# ---------------------------------------
# Processing record 155 for the city: venice
# ---------------------------------------
# Processing record 156 for the city: chokurdakh
# ---------------------------------------
# Processing record 157 for the city: pangnirtung
# ---------------------------------------
# Processing record 158 for the city: isangel
# ---------------------------------------
# ondorhaan not found in OpenWeather database.
# ---------------------------------------
# Processing record 160 for the city: kochevo
# ---------------------------------------
# Processing record 161 for the city: high level
# ---------------------------------------
# Processing record 162 for the city: touros
# ---------------------------------------
# Processing record 163 for the city: coos bay
# ---------------------------------------
# Processing record 164 for the city: vaini
# ---------------------------------------
# Processing record 165 for the city: kochi
# ---------------------------------------
# Processing record 166 for the city: colesberg
# ---------------------------------------
# kuche not found in OpenWeather database.
# ---------------------------------------
# Processing record 168 for the city: bay roberts
# ---------------------------------------
# Processing record 169 for the city: maridi
# ---------------------------------------
# Processing record 170 for the city: te anau
# ---------------------------------------
# Processing record 171 for the city: luderitz
# ---------------------------------------
# Processing record 172 for the city: karratha
# ---------------------------------------
# Processing record 173 for the city: kurilsk
# ---------------------------------------
# Processing record 174 for the city: fortuna
# ---------------------------------------
# Processing record 175 for the city: westport
# ---------------------------------------
# Processing record 176 for the city: cherskiy
# ---------------------------------------
# belushya guba not found in OpenWeather database.
# ---------------------------------------
# Processing record 178 for the city: sistranda
# ---------------------------------------
# Processing record 179 for the city: east london
# ---------------------------------------
# Processing record 180 for the city: hay river
# ---------------------------------------
# Processing record 181 for the city: qui nhon
# ---------------------------------------
# jahrom not found in OpenWeather database.
# ---------------------------------------
# Processing record 183 for the city: ust-nera
# ---------------------------------------
# Processing record 184 for the city: severo-kurilsk
# ---------------------------------------
# Processing record 185 for the city: kasongo-lunda
# ---------------------------------------
# Processing record 186 for the city: chapais
# ---------------------------------------
# Processing record 187 for the city: ashtian
# ---------------------------------------
# Processing record 188 for the city: atar
# ---------------------------------------
# Processing record 189 for the city: port-cartier
# ---------------------------------------
# Processing record 190 for the city: port hardy
# ---------------------------------------
# Processing record 191 for the city: atikokan
# ---------------------------------------
# Processing record 192 for the city: san patricio
# ---------------------------------------
# Processing record 193 for the city: praia da vitoria
# ---------------------------------------
# Processing record 194 for the city: el guayabito
# ---------------------------------------
# Processing record 195 for the city: flin flon
# ---------------------------------------
# Processing record 196 for the city: colares
# ---------------------------------------
# Processing record 197 for the city: vila do maio
# ---------------------------------------
# Processing record 198 for the city: bambanglipuro
# ---------------------------------------
# Processing record 199 for the city: castro
# ---------------------------------------
# Processing record 200 for the city: bintulu
# ---------------------------------------
# naftah not found in OpenWeather database.
# ---------------------------------------
# Processing record 202 for the city: kologriv
# ---------------------------------------
# Processing record 203 for the city: cockburn town
# ---------------------------------------
# Processing record 204 for the city: ajaccio
# ---------------------------------------
# Processing record 205 for the city: bonavista
# ---------------------------------------
# Processing record 206 for the city: kautokeino
# ---------------------------------------
# Processing record 207 for the city: opuwo
# ---------------------------------------
# Processing record 208 for the city: mgandu
# ---------------------------------------
# Processing record 209 for the city: perth
# ---------------------------------------
# Processing record 210 for the city: hobart
# ---------------------------------------
# Processing record 211 for the city: faanui
# ---------------------------------------
# Processing record 212 for the city: washington
# ---------------------------------------
# Processing record 213 for the city: biak
# ---------------------------------------
# saleaula not found in OpenWeather database.
# ---------------------------------------
# Processing record 215 for the city: talavera de la reina
# ---------------------------------------
# Processing record 216 for the city: manta
# ---------------------------------------
# Processing record 217 for the city: jagodina
# ---------------------------------------
# Processing record 218 for the city: palmer
# ---------------------------------------
# Processing record 219 for the city: kumluca
# ---------------------------------------
# cockburn harbour not found in OpenWeather database.
# ---------------------------------------
# Processing record 221 for the city: arandis
# ---------------------------------------
# Processing record 222 for the city: bitung
# ---------------------------------------
# Processing record 223 for the city: ribeira grande
# ---------------------------------------
# mys shmidta not found in OpenWeather database.
# ---------------------------------------
# Processing record 225 for the city: wasilla
# ---------------------------------------
# attawapiskat not found in OpenWeather database.
# ---------------------------------------
# marcona not found in OpenWeather database.
# ---------------------------------------
# Processing record 228 for the city: aden
# ---------------------------------------
# Processing record 229 for the city: kununurra
# ---------------------------------------
# Processing record 230 for the city: kalmunai
# ---------------------------------------
# Processing record 231 for the city: nizwa
# ---------------------------------------
# Processing record 232 for the city: tahe
# ---------------------------------------
# Processing record 233 for the city: elliot lake
# ---------------------------------------
# Processing record 234 for the city: camacha
# ---------------------------------------
# cagayan de tawi-tawi not found in OpenWeather database.
# ---------------------------------------
# Processing record 236 for the city: todos santos
# ---------------------------------------
# Processing record 237 for the city: villacarrillo
# ---------------------------------------
# Processing record 238 for the city: jever
# ---------------------------------------
# Processing record 239 for the city: asau
# ---------------------------------------
# rungata not found in OpenWeather database.
# ---------------------------------------
# Processing record 241 for the city: rawah
# ---------------------------------------
# lolua not found in OpenWeather database.
# ---------------------------------------
# Processing record 243 for the city: tuxpan
# ---------------------------------------
# Processing record 244 for the city: karoi
# ---------------------------------------
# Processing record 245 for the city: karasuk
# ---------------------------------------
# Processing record 246 for the city: morant bay
# ---------------------------------------
# Processing record 247 for the city: conroe
# ---------------------------------------
# Processing record 248 for the city: simao
# ---------------------------------------
# Processing record 249 for the city: plainview
# ---------------------------------------
# Processing record 250 for the city: hermanus
# ---------------------------------------
# Processing record 251 for the city: farsund
# ---------------------------------------
# Processing record 252 for the city: cairns
# ---------------------------------------
# Processing record 253 for the city: nortelandia
# ---------------------------------------
# Processing record 254 for the city: yeniseysk
# ---------------------------------------
# Processing record 255 for the city: wakiso
# ---------------------------------------
# Processing record 256 for the city: wembley
# ---------------------------------------
# Processing record 257 for the city: mount isa
# ---------------------------------------
# Processing record 258 for the city: guerrero negro
# ---------------------------------------
# Processing record 259 for the city: malinyi
# ---------------------------------------
# Processing record 260 for the city: thinadhoo
# ---------------------------------------
# Processing record 261 for the city: kruisfontein
# ---------------------------------------
# Processing record 262 for the city: ballitoville
# ---------------------------------------
# Processing record 263 for the city: pundaguitan
# ---------------------------------------
# Processing record 264 for the city: gubkinskiy
# ---------------------------------------
# Processing record 265 for the city: cognac
# ---------------------------------------
# Processing record 266 for the city: rubiataba
# ---------------------------------------
# Processing record 267 for the city: zmeinogorsk
# ---------------------------------------
# Processing record 268 for the city: port-gentil
# ---------------------------------------
# Processing record 269 for the city: imbituba
# ---------------------------------------
# Processing record 270 for the city: lodja
# ---------------------------------------
# Processing record 271 for the city: pevek
# ---------------------------------------
# Processing record 272 for the city: muroto
# ---------------------------------------
# Processing record 273 for the city: dhidhdhoo
# ---------------------------------------
# vallee-jonction not found in OpenWeather database.
# ---------------------------------------
# Processing record 275 for the city: nantucket
# ---------------------------------------
# Processing record 276 for the city: ajdabiya
# ---------------------------------------
# Processing record 277 for the city: bucerias
# ---------------------------------------
# Processing record 278 for the city: haines junction
# ---------------------------------------
# Processing record 279 for the city: amli
# ---------------------------------------
# Processing record 280 for the city: balabac
# ---------------------------------------
# Processing record 281 for the city: rudsar
# ---------------------------------------
# Processing record 282 for the city: thetford mines
# ---------------------------------------
# Processing record 283 for the city: tiksi
# ---------------------------------------
# Processing record 284 for the city: pisco
# ---------------------------------------
# Processing record 285 for the city: namibe
# ---------------------------------------
# Processing record 286 for the city: cidreira
# ---------------------------------------
# Processing record 287 for the city: novo aripuana
# ---------------------------------------
# Processing record 288 for the city: fort saint james
# ---------------------------------------
# palabuhanratu not found in OpenWeather database.
# ---------------------------------------
# Processing record 290 for the city: ouallam
# ---------------------------------------
# Processing record 291 for the city: conceicao do araguaia
# ---------------------------------------
# gorno-chuyskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 293 for the city: massy
# ---------------------------------------
# Processing record 294 for the city: olafsvik
# ---------------------------------------
# Processing record 295 for the city: tutoia
# ---------------------------------------
# Processing record 296 for the city: rania
# ---------------------------------------
# Processing record 297 for the city: skjervoy
# ---------------------------------------
# Processing record 298 for the city: talas
# ---------------------------------------
# Processing record 299 for the city: borgarnes
# ---------------------------------------
# Processing record 300 for the city: mayya
# ---------------------------------------
# Processing record 301 for the city: lorengau
# ---------------------------------------
# Processing record 302 for the city: san policarpo
# ---------------------------------------
# Processing record 303 for the city: san jose
# ---------------------------------------
# Processing record 304 for the city: maceio
# ---------------------------------------
# felidhoo not found in OpenWeather database.
# ---------------------------------------
# Processing record 306 for the city: okha
# ---------------------------------------
# Processing record 307 for the city: benguela
# ---------------------------------------
# Processing record 308 for the city: yaan
# ---------------------------------------
# Processing record 309 for the city: finnsnes
# ---------------------------------------
# Processing record 310 for the city: walvis bay
# ---------------------------------------
# Processing record 311 for the city: san vicente de canete
# ---------------------------------------
# Processing record 312 for the city: nordhausen
# ---------------------------------------
# Processing record 313 for the city: krasnogorsk
# ---------------------------------------
# khonuu not found in OpenWeather database.
# ---------------------------------------
# Processing record 315 for the city: khandbari
# ---------------------------------------
# Processing record 316 for the city: nishihara
# ---------------------------------------
# Processing record 317 for the city: gorele
# ---------------------------------------
# Processing record 318 for the city: grindavik
# ---------------------------------------
# Processing record 319 for the city: buje
# ---------------------------------------
# Processing record 320 for the city: shenjiamen
# ---------------------------------------
# Processing record 321 for the city: tasiilaq
# ---------------------------------------
# Processing record 322 for the city: clyde river
# ---------------------------------------
# Processing record 323 for the city: igarka
# ---------------------------------------
# shchelyayur not found in OpenWeather database.
# ---------------------------------------
# Processing record 325 for the city: kupang
# ---------------------------------------
# Processing record 326 for the city: sambava
# ---------------------------------------
# Processing record 327 for the city: birao
# ---------------------------------------
# grand river south east not found in OpenWeather database.
# ---------------------------------------
# Processing record 329 for the city: mehamn
# ---------------------------------------
# Processing record 330 for the city: koumac
# ---------------------------------------
# Processing record 331 for the city: segezha
# ---------------------------------------
# Processing record 332 for the city: yulara
# ---------------------------------------
# Processing record 333 for the city: longyearbyen
# ---------------------------------------
# Processing record 334 for the city: olkhovka
# ---------------------------------------
# Processing record 335 for the city: khasan
# ---------------------------------------
# Processing record 336 for the city: haapiti
# ---------------------------------------
# Processing record 337 for the city: tinskoy
# ---------------------------------------
# Processing record 338 for the city: turinsk
# ---------------------------------------
# Processing record 339 for the city: diplo
# ---------------------------------------
# Processing record 340 for the city: kjollefjord
# ---------------------------------------
# Processing record 341 for the city: ust-tsilma
# ---------------------------------------
# Processing record 342 for the city: palatka
# ---------------------------------------
# Processing record 343 for the city: tambacounda
# ---------------------------------------
# Processing record 344 for the city: aykhal
# ---------------------------------------
# Processing record 345 for the city: taoudenni
# ---------------------------------------
# Processing record 346 for the city: buhl
# ---------------------------------------
# Processing record 347 for the city: zinder
# ---------------------------------------
# Processing record 348 for the city: yumbe
# ---------------------------------------
# Processing record 349 for the city: mayor pablo lagerenza
# ---------------------------------------
# Processing record 350 for the city: meshchovsk
# ---------------------------------------
# Processing record 351 for the city: sorland
# ---------------------------------------
# Processing record 352 for the city: barinas
# ---------------------------------------
# Processing record 353 for the city: chenzhou
# ---------------------------------------
# Processing record 354 for the city: muros
# ---------------------------------------
# Processing record 355 for the city: buala
# ---------------------------------------
# Processing record 356 for the city: vestmanna
# ---------------------------------------
# Processing record 357 for the city: bereda
# ---------------------------------------
# Processing record 358 for the city: meulaboh
# ---------------------------------------
# Processing record 359 for the city: lavrentiya
# ---------------------------------------
# Processing record 360 for the city: port lincoln
# ---------------------------------------
# Processing record 361 for the city: nouadhibou
# ---------------------------------------
# Processing record 362 for the city: siloam springs
# ---------------------------------------
# Processing record 363 for the city: rio grande
# ---------------------------------------
# Processing record 364 for the city: misawa
# ---------------------------------------
# Processing record 365 for the city: pullman
# ---------------------------------------
# Processing record 366 for the city: ciudad dario
# ---------------------------------------
# Processing record 367 for the city: leningradskiy
# ---------------------------------------
# Processing record 368 for the city: cerrito
# ---------------------------------------
# Processing record 369 for the city: takaka
# ---------------------------------------
# Processing record 370 for the city: luebo
# ---------------------------------------
# Processing record 371 for the city: honiara
# ---------------------------------------
# Processing record 372 for the city: kaitangata
# ---------------------------------------
# Processing record 373 for the city: nalut
# ---------------------------------------
# Processing record 374 for the city: vila
# ---------------------------------------
# Processing record 375 for the city: la ronge
# ---------------------------------------
# tawnat not found in OpenWeather database.
# ---------------------------------------
# Processing record 377 for the city: caravelas
# ---------------------------------------
# Processing record 378 for the city: tazovskiy
# ---------------------------------------
# Processing record 379 for the city: khandyga
# ---------------------------------------
# Processing record 380 for the city: taungdwingyi
# ---------------------------------------
# Processing record 381 for the city: khatanga
# ---------------------------------------
# Processing record 382 for the city: cordoba
# ---------------------------------------
# Processing record 383 for the city: jumla
# ---------------------------------------
# Processing record 384 for the city: russell
# ---------------------------------------
# Processing record 385 for the city: inhambane
# ---------------------------------------
# Processing record 386 for the city: sonqor
# ---------------------------------------
# okandja not found in OpenWeather database.
# ---------------------------------------
# Processing record 388 for the city: nanortalik
# ---------------------------------------
# Processing record 389 for the city: carballo
# ---------------------------------------
# Processing record 390 for the city: esperanza
# ---------------------------------------
# Processing record 391 for the city: erenhot
# ---------------------------------------
# Processing record 392 for the city: riyadh
# ---------------------------------------
# Processing record 393 for the city: broken hill
# ---------------------------------------
# Processing record 394 for the city: troitsko-pechorsk
# ---------------------------------------
# warqla not found in OpenWeather database.
# ---------------------------------------
# Processing record 396 for the city: tanete
# ---------------------------------------
# Processing record 397 for the city: norsup
# ---------------------------------------
# Processing record 398 for the city: ojinaga
# ---------------------------------------
# Processing record 399 for the city: guanajay
# ---------------------------------------
# Processing record 400 for the city: eyl
# ---------------------------------------
# Processing record 401 for the city: ballina
# ---------------------------------------
# Processing record 402 for the city: wanning
# ---------------------------------------
# Processing record 403 for the city: felanitx
# ---------------------------------------
# Processing record 404 for the city: omis
# ---------------------------------------
# Processing record 405 for the city: constitucion
# ---------------------------------------
# Processing record 406 for the city: norman wells
# ---------------------------------------
# Processing record 407 for the city: minab
# ---------------------------------------
# Processing record 408 for the city: aitape
# ---------------------------------------
# Processing record 409 for the city: sabang
# ---------------------------------------
# Processing record 410 for the city: naze
# ---------------------------------------
# Processing record 411 for the city: bethel
# ---------------------------------------
# Processing record 412 for the city: shimanovsk
# ---------------------------------------
# Processing record 413 for the city: ercis
# ---------------------------------------
# Processing record 414 for the city: brae
# ---------------------------------------
# Processing record 415 for the city: gamba
# ---------------------------------------
# Processing record 416 for the city: tadine
# ---------------------------------------
# Processing record 417 for the city: hammerfest
# ---------------------------------------
# Processing record 418 for the city: encruzilhada do sul
# ---------------------------------------
# Processing record 419 for the city: asyut
# ---------------------------------------
# Processing record 420 for the city: clovis
# ---------------------------------------
# Processing record 421 for the city: lobez
# ---------------------------------------
# Processing record 422 for the city: sarangani
# ---------------------------------------
# ardistan not found in OpenWeather database.
# ---------------------------------------
# Processing record 424 for the city: rio gallegos
# ---------------------------------------
# Processing record 425 for the city: ponoka
# ---------------------------------------
# Processing record 426 for the city: los andes
# ---------------------------------------
# Processing record 427 for the city: ostrovnoy
# ---------------------------------------
# Processing record 428 for the city: cabo san lucas
# ---------------------------------------
# ust-kamchatsk not found in OpenWeather database.
# ---------------------------------------
# Processing record 430 for the city: gulu
# ---------------------------------------
# Processing record 431 for the city: otavi
# ---------------------------------------
# Processing record 432 for the city: veraval
# ---------------------------------------
# Processing record 433 for the city: phan thiet
# ---------------------------------------
# Processing record 434 for the city: vaitape
# ---------------------------------------
# Processing record 435 for the city: savannah bight
# ---------------------------------------
# Processing record 436 for the city: bandarbeyla
# ---------------------------------------
# Processing record 437 for the city: beloha
# ---------------------------------------
# Processing record 438 for the city: santa isabel do rio negro
# ---------------------------------------
# Processing record 439 for the city: tautira
# ---------------------------------------
# Processing record 440 for the city: deder
# ---------------------------------------
# Processing record 441 for the city: boende
# ---------------------------------------
# Processing record 442 for the city: lindi
# ---------------------------------------
# Processing record 443 for the city: nyrob
# ---------------------------------------
# Processing record 444 for the city: ponta delgada
# ---------------------------------------
# Processing record 445 for the city: majene
# ---------------------------------------
# Processing record 446 for the city: aktas
# ---------------------------------------
# Processing record 447 for the city: tabas
# ---------------------------------------
# Processing record 448 for the city: doha
# ---------------------------------------
# Processing record 449 for the city: talnakh
# ---------------------------------------
# Processing record 450 for the city: ahipara
# ---------------------------------------
# Processing record 451 for the city: kankon
# ---------------------------------------
# Processing record 452 for the city: plouzane
# ---------------------------------------
# preobrazhenskaya not found in OpenWeather database.
# ---------------------------------------
# Processing record 454 for the city: victoria
# ---------------------------------------
# Processing record 455 for the city: dudinka
# ---------------------------------------
# Processing record 456 for the city: chumikan
# ---------------------------------------
# Processing record 457 for the city: dordrecht
# ---------------------------------------
# Processing record 458 for the city: jiutai
# ---------------------------------------
# Processing record 459 for the city: lasa
# ---------------------------------------
# Processing record 460 for the city: danilovka
# ---------------------------------------
# Processing record 461 for the city: sartell
# ---------------------------------------
# Processing record 462 for the city: puksoozero
# ---------------------------------------
# Processing record 463 for the city: torit
# ---------------------------------------
# Processing record 464 for the city: monrovia
# ---------------------------------------
# Processing record 465 for the city: telimele
# ---------------------------------------
# Processing record 466 for the city: sampit
# ---------------------------------------
# Processing record 467 for the city: burnie
# ---------------------------------------
# Processing record 468 for the city: snasa
# ---------------------------------------
# Processing record 469 for the city: zhigansk
# ---------------------------------------
# Processing record 470 for the city: roebourne
# ---------------------------------------
# Processing record 471 for the city: belmonte
# ---------------------------------------
# Processing record 472 for the city: husavik
# ---------------------------------------
# Processing record 473 for the city: santa rosa
# ---------------------------------------
# Processing record 474 for the city: hovd
# ---------------------------------------
# Processing record 475 for the city: longido
# ---------------------------------------
# Processing record 476 for the city: ossora
# ---------------------------------------
# Processing record 477 for the city: newton aycliffe
# ---------------------------------------
# Processing record 478 for the city: san-pedro
# ---------------------------------------
# paradwip not found in OpenWeather database.
# ---------------------------------------
# Processing record 480 for the city: trenggalek
# ---------------------------------------
# labutta not found in OpenWeather database.
# ---------------------------------------
# Processing record 482 for the city: iwaki
# ---------------------------------------
# Processing record 483 for the city: souillac
# ---------------------------------------
# Processing record 484 for the city: the valley
# ---------------------------------------
# Processing record 485 for the city: waw
# ---------------------------------------
# Processing record 486 for the city: outlook
# ---------------------------------------
# Processing record 487 for the city: tara
# ---------------------------------------
# Processing record 488 for the city: pitimbu
# ---------------------------------------
# Processing record 489 for the city: bahir dar
# ---------------------------------------
# Processing record 490 for the city: coahuayana
# ---------------------------------------
# Processing record 491 for the city: juneau
# ---------------------------------------
# Processing record 492 for the city: phangnga
# ---------------------------------------
# Processing record 493 for the city: wajid
# ---------------------------------------
# Processing record 494 for the city: kenai
# ---------------------------------------
# Processing record 495 for the city: jerusalem
# ---------------------------------------
# Processing record 496 for the city: chuy
# ---------------------------------------
# samusu not found in OpenWeather database.
# ---------------------------------------
# Processing record 498 for the city: srednekolymsk
# ---------------------------------------
# mentok not found in OpenWeather database.
# ---------------------------------------
# Processing record 500 for the city: boyabat
# ---------------------------------------
# Processing record 501 for the city: buraydah
# ---------------------------------------
# grand centre not found in OpenWeather database.
# ---------------------------------------
# Processing record 503 for the city: coruripe
# ---------------------------------------
# Processing record 504 for the city: acajutla
# ---------------------------------------
# Processing record 505 for the city: baft
# ---------------------------------------
# Processing record 506 for the city: hervey bay
# ---------------------------------------
# Processing record 507 for the city: sioux lookout
# ---------------------------------------
# Processing record 508 for the city: sabha
# ---------------------------------------
# Processing record 509 for the city: lakes entrance
# ---------------------------------------
# Processing record 510 for the city: sakaiminato
# ---------------------------------------
# balimo not found in OpenWeather database.
# ---------------------------------------
# Processing record 512 for the city: dunedin
# ---------------------------------------
# Processing record 513 for the city: morondava
# ---------------------------------------
# Processing record 514 for the city: oktyabrskiy
# ---------------------------------------
# Processing record 515 for the city: uthal
# ---------------------------------------
# Processing record 516 for the city: heswall
# ---------------------------------------
# vaitupu not found in OpenWeather database.
# ---------------------------------------
# Processing record 518 for the city: lerwick
# ---------------------------------------
# armacao dos buzios not found in OpenWeather database.
# ---------------------------------------
# Processing record 520 for the city: seropedica
# ---------------------------------------
# Processing record 521 for the city: dire
# ---------------------------------------
# Processing record 522 for the city: lac du bonnet
# ---------------------------------------
# tasbuget not found in OpenWeather database.
# ---------------------------------------
# louisbourg not found in OpenWeather database.
# ---------------------------------------
# Processing record 525 for the city: chama
# ---------------------------------------
# Processing record 526 for the city: moen
# ---------------------------------------
# Processing record 527 for the city: lokosovo
# ---------------------------------------
# Processing record 528 for the city: karasburg
# ---------------------------------------
# Processing record 529 for the city: xiangxiang
# ---------------------------------------
# Processing record 530 for the city: kapuskasing
# ---------------------------------------
# Processing record 531 for the city: mae tha
# ---------------------------------------
# Processing record 532 for the city: sunzha
# ---------------------------------------
# Processing record 533 for the city: bridgewater
# ---------------------------------------
# Processing record 534 for the city: lompoc
# ---------------------------------------
# agva not found in OpenWeather database.
# ---------------------------------------
# Processing record 536 for the city: borogontsy
# ---------------------------------------
# Processing record 537 for the city: charters towers
# ---------------------------------------
# Processing record 538 for the city: ust-kuyga
# ---------------------------------------
# Processing record 539 for the city: berlevag
# ---------------------------------------
# Processing record 540 for the city: katangli
# ---------------------------------------
# Processing record 541 for the city: nara
# ---------------------------------------
# Processing record 542 for the city: porto velho
# ---------------------------------------
# Processing record 543 for the city: puerto del rosario
# ---------------------------------------
# Processing record 544 for the city: krasnyy chikoy
# ---------------------------------------
# Processing record 545 for the city: mansfield
# ---------------------------------------
# Processing record 546 for the city: sao domingos do maranhao
# ---------------------------------------
# Processing record 547 for the city: gushikawa
# ---------------------------------------
# Processing record 548 for the city: narsaq
# ---------------------------------------
# Processing record 549 for the city: atherton
# ---------------------------------------
# Processing record 550 for the city: kindu
# ---------------------------------------
# Processing record 551 for the city: vryburg
# ---------------------------------------
# Processing record 552 for the city: jinchang
# ---------------------------------------
# Processing record 553 for the city: xuddur
# ---------------------------------------
# Processing record 554 for the city: sri aman
# ---------------------------------------
# Processing record 555 for the city: junin
# ---------------------------------------
# Processing record 556 for the city: vostok
# ---------------------------------------
# Processing record 557 for the city: beira
# ---------------------------------------
# Processing record 558 for the city: sur
# ---------------------------------------
# Processing record 559 for the city: leshukonskoye
# ---------------------------------------
# Processing record 560 for the city: aquidauana
# ---------------------------------------
# Processing record 561 for the city: paamiut
# ---------------------------------------
# Processing record 562 for the city: nakhon thai
# ---------------------------------------
# Processing record 563 for the city: sena madureira
# ---------------------------------------
# karaul not found in OpenWeather database.
# ---------------------------------------
# Processing record 565 for the city: wittenberge
# ---------------------------------------
# Processing record 566 for the city: mwene-ditu
# ---------------------------------------
# Processing record 567 for the city: lufilufi
# ---------------------------------------
# Processing record 568 for the city: gympie
# ---------------------------------------
# Processing record 569 for the city: bubaque
# ---------------------------------------
# Processing record 570 for the city: portland
# ---------------------------------------
# Processing record 571 for the city: broome
# ---------------------------------------
# Processing record 572 for the city: bizhbulyak
# ---------------------------------------
# Processing record 573 for the city: cap malheureux
# ---------------------------------------
# Processing record 574 for the city: yelatma
# ---------------------------------------
# Processing record 575 for the city: rupert
# ---------------------------------------
# Processing record 576 for the city: labuhan
# ---------------------------------------
# Processing record 577 for the city: ancud
# ---------------------------------------
# Processing record 578 for the city: akyab
# ---------------------------------------
# Processing record 579 for the city: richards bay
# ---------------------------------------
# Processing record 580 for the city: bharthana
# ---------------------------------------
# Processing record 581 for the city: agadir
# ---------------------------------------
# Processing record 582 for the city: bireun
# ---------------------------------------
# Processing record 583 for the city: kidal
# ---------------------------------------
# Processing record 584 for the city: kuryk
# ---------------------------------------
# Processing record 585 for the city: willowmore
# ---------------------------------------
# Processing record 586 for the city: ambulu
# ---------------------------------------
# tumannyy not found in OpenWeather database.
# ---------------------------------------
# Processing record 588 for the city: alice springs
# ---------------------------------------
# Processing record 589 for the city: primorsk
# ---------------------------------------
# Processing record 590 for the city: xining
# ---------------------------------------
# Processing record 591 for the city: novocheremshansk
# ---------------------------------------
# Processing record 592 for the city: arlit
# ---------------------------------------
# Processing record 593 for the city: filingue
# ---------------------------------------
# Processing record 594 for the city: marzuq
# ---------------------------------------
# Processing record 595 for the city: krabi
# ---------------------------------------
# Processing record 596 for the city: tamandare
# ---------------------------------------
# Processing record 597 for the city: olinda
# ---------------------------------------
# Processing record 598 for the city: mirnyy
# ---------------------------------------
# lalomanu not found in OpenWeather database.
# ---------------------------------------
# Processing record 600 for the city: port blair
# ---------------------------------------
# Processing record 601 for the city: college
# ---------------------------------------
# Processing record 602 for the city: kula
# ---------------------------------------
# Processing record 603 for the city: esperance
# ---------------------------------------
# Processing record 604 for the city: baijiantan
# ---------------------------------------
# Processing record 605 for the city: verkhnevilyuysk
# ---------------------------------------
# Processing record 606 for the city: ludwigslust
# ---------------------------------------
# Processing record 607 for the city: komsomolskiy
# ---------------------------------------

# %%
len(city_name)
# Out:
# 552

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, temp, humidity, cloudiness, and wind speed.
weather_dict = {
    "City": city_name,
    "Latitude": lat,
    "Temperature (F)": temp_max,
    "Humidity (%)": humidity,
    "Cloudiness (%)": clouds,
    "Wind Speed (mph)": wind_speed,
    
    
}
weather_data = pd.DataFrame(weather_dict)
now = datetime.now()

#Export weather data to csv.
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)

#Display df.
weather_data.head()
# Out:
#             City  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0      Busselton  -33.6500            73.99            45             100
# 1         Albany   42.6001            37.00            65              92
# 2  Mount Gambier  -37.8333            57.20            82              90
# 3      Hithadhoo   -0.6000            81.46            73              68
# 4      Ilulissat   69.2167            19.40            53              75
#
#    Wind Speed (mph)
# 0              1.01
# 1              1.99
# 2             10.36
# 3              6.44
# 4             21.85

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hi_hum = weather_data.loc[weather_data['Humidity (%)'] > 100]
print(hi_hum)
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph), Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Temperature (F)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Maximum Temperature by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('world_temp_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that maximum daily temperature does go down as one moves further away from the equator (both North and South). Max. Temp. at latitudes further away from the equator are higher in the southern hemisphere than in the northern hemisphere currently. This latter observation is perhaps explained by the southern hemisphere being in summer, while the northern hemisphere is in winter currently. Due to the tilt of the Earth's axis, the southern hemisphere is facing to the sun and the northern hemisphere is facing away from the sun.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Humidity (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Humidity by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('world_hum_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no particular relationship between percent humidity and latitude. There is some clumping of points in the 80% to 100% humidity at latitudes above 40 degrees north, but no clear correlation to my eye.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Cloudiness (%)']


plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Cloudiness by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('world_cloud_lat.png')
plt.show()

# %% [markdown]
# This plot demonstrates that there is no clear relationship between cloudiness and latitude. There is some clumping of data at 0%, 20%, 40%, ~75%, and 100%. This makes me think of human error in assigning the values.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Wind Speed (mph)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Wind Speed by Latitude (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('world_wspeed_lat.png')
plt.show()

# %% [markdown]
# I see no clear relationship between wind speed and latitude on this plot.

# %% [markdown]
# ## Linear Regression

# %%
nh_data = weather_data.loc[weather_data['Latitude'] >=0]
sh_data = weather_data.loc[weather_data['Latitude'] <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('nh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Northern Hemisphere is -0.86

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Max. Temp. by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('sh_temp_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Max. Temp (F) and Latitude in the Southern Hemisphere is 0.63

# %% [markdown]
# Analysis of Max. Temp. by latitude in both the southern and northern hemispheres show a strong correlation with the Max. Temp. getting higher as we get closer to the equator. In the southern hemisphere this manifests as a positve correlation (equator is on the right of the x-axis), in the northern hemisphere a negative correlation describes the same trend (equator is on the left of the x-axis).

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('nh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Northern Hemisphere is 0.53

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Humidity by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('sh_hum_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Humidity (%) and Latitude in the Southern Hemisphere is 0.17

# %% [markdown]
# In this analysis, humidity is increasing as we move further north from the equator and decreasing as we move further south from the equator. The Pearson correlation coefficient deonstrates a stronger correlation for the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('nh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Northern Hemisphere is 0.29

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Cloudiness by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('sh_cloud_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Cloudiness (%) and Latitude in the Southern Hemisphere is 0.14

# %% [markdown]
# Analysis of cloudiness versus latitude shows a slight trend for cloudiness to increase in the southern hemisphere as we move towards the equator. In the northern hemisphere, cloudiness is increasing as we move away from the equator. In both the northern and the southern hemispheres there are clumps around 0% and near 100%, but no clear correlation to latitude is evident to my eye.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nh_data['Latitude']
y_values = nh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Northern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('nh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Northern Hemisphere is 0.0

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sh_data['Latitude']
y_values = sh_data['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(1,figsize=(10,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.title('Wind Speed by Latitude-Southern Hemisphere (data acquired ' + str(now) + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('sh_ws_lat.png')
plt.show()

print(f"The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The Pearson correlation coefficient between Wind Speed and Latitude in the Southern Hemisphere is -0.19

# %% [markdown]
# These two plots show no correlation between wind speed and latitude in the northern hemisphere and a slight decrease in wind speed as we move towards the equator in the southern hemisphere. The correlation in the southern hemisphere appears weak.
