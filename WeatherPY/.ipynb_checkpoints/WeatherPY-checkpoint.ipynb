# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 646

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
city_name=[]
lat = []
temp_max = []
humidity = []
clouds = []
wind_speed = []
data_date = []


# Loop through the list of cities and perform a request for data on each

count=0
print("Start API Call to OpenWeather Database ")
print("---------------------------------------")

for city in cities:
    try:
        count += 1
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        data_date.append(response['dt'])
        print(f"Processing record {count} for the city: {city}")
    
    except:
        #cities.remove(city)
        print(f"{city} not found in OpenWeather database.")
        pass

    print("---------------------------------------")
# Out:
# Start API Call to OpenWeather Database
# ---------------------------------------
# Processing record 1 for the city: cape town
# ---------------------------------------
# Processing record 2 for the city: chuy
# ---------------------------------------
# opobo not found in OpenWeather database.
# ---------------------------------------
# Processing record 4 for the city: anadyr
# ---------------------------------------
# Processing record 5 for the city: rikitea
# ---------------------------------------
# Processing record 6 for the city: thompson
# ---------------------------------------
# Processing record 7 for the city: svetlyy
# ---------------------------------------
# Processing record 8 for the city: nalut
# ---------------------------------------
# Processing record 9 for the city: luderitz
# ---------------------------------------
# Processing record 10 for the city: kaitangata
# ---------------------------------------
# Processing record 11 for the city: ushuaia
# ---------------------------------------
# Processing record 12 for the city: puerto ayora
# ---------------------------------------
# Processing record 13 for the city: castro
# ---------------------------------------
# Processing record 14 for the city: keti bandar
# ---------------------------------------
# Processing record 15 for the city: kavieng
# ---------------------------------------
# Processing record 16 for the city: marang
# ---------------------------------------
# Processing record 17 for the city: upernavik
# ---------------------------------------
# Processing record 18 for the city: khatanga
# ---------------------------------------
# Processing record 19 for the city: tiksi
# ---------------------------------------
# Processing record 20 for the city: bengkulu
# ---------------------------------------
# saleaula not found in OpenWeather database.
# ---------------------------------------
# Processing record 22 for the city: moreno valley
# ---------------------------------------
# Processing record 23 for the city: barrow
# ---------------------------------------
# halalo not found in OpenWeather database.
# ---------------------------------------
# Processing record 25 for the city: iqaluit
# ---------------------------------------
# Processing record 26 for the city: kapaa
# ---------------------------------------
# Processing record 27 for the city: zacualpan
# ---------------------------------------
# Processing record 28 for the city: bethel
# ---------------------------------------
# Processing record 29 for the city: hermanus
# ---------------------------------------
# karauzyak not found in OpenWeather database.
# ---------------------------------------
# Processing record 31 for the city: mahebourg
# ---------------------------------------
# Processing record 32 for the city: hammerfest
# ---------------------------------------
# belushya guba not found in OpenWeather database.
# ---------------------------------------
# Processing record 34 for the city: huaiyin
# ---------------------------------------
# Processing record 35 for the city: opuwo
# ---------------------------------------
# barentsburg not found in OpenWeather database.
# ---------------------------------------
# Processing record 37 for the city: nan
# ---------------------------------------
# Processing record 38 for the city: mataura
# ---------------------------------------
# illoqqortoormiut not found in OpenWeather database.
# ---------------------------------------
# Processing record 40 for the city: riyadh
# ---------------------------------------
# Processing record 41 for the city: dikson
# ---------------------------------------
# Processing record 42 for the city: carnarvon
# ---------------------------------------
# armacao dos buzios not found in OpenWeather database.
# ---------------------------------------
# Processing record 44 for the city: reconquista
# ---------------------------------------
# Processing record 45 for the city: davila
# ---------------------------------------
# Processing record 46 for the city: pochutla
# ---------------------------------------
# Processing record 47 for the city: talnakh
# ---------------------------------------
# Processing record 48 for the city: avarua
# ---------------------------------------
# Processing record 49 for the city: zhigansk
# ---------------------------------------
# Processing record 50 for the city: cabo san lucas
# ---------------------------------------
# Processing record 51 for the city: tuktoyaktuk
# ---------------------------------------
# Processing record 52 for the city: naron
# ---------------------------------------
# Processing record 53 for the city: cao bang
# ---------------------------------------
# Processing record 54 for the city: bam
# ---------------------------------------
# Processing record 55 for the city: pemangkat
# ---------------------------------------
# Processing record 56 for the city: faanui
# ---------------------------------------
# taolanaro not found in OpenWeather database.
# ---------------------------------------
# Processing record 58 for the city: ponta do sol
# ---------------------------------------
# Processing record 59 for the city: yumen
# ---------------------------------------
# Processing record 60 for the city: hilo
# ---------------------------------------
# Processing record 61 for the city: korla
# ---------------------------------------
# Processing record 62 for the city: richards bay
# ---------------------------------------
# Processing record 63 for the city: tazovskiy
# ---------------------------------------
# Processing record 64 for the city: andros town
# ---------------------------------------
# Processing record 65 for the city: albany
# ---------------------------------------
# Processing record 66 for the city: tasiilaq
# ---------------------------------------
# Processing record 67 for the city: dingle
# ---------------------------------------
# Processing record 68 for the city: fort nelson
# ---------------------------------------
# Processing record 69 for the city: najran
# ---------------------------------------
# Processing record 70 for the city: amahai
# ---------------------------------------
# Processing record 71 for the city: bulolo
# ---------------------------------------
# Processing record 72 for the city: nyurba
# ---------------------------------------
# Processing record 73 for the city: ullal
# ---------------------------------------
# Processing record 74 for the city: busselton
# ---------------------------------------
# Processing record 75 for the city: talaya
# ---------------------------------------
# Processing record 76 for the city: price
# ---------------------------------------
# Processing record 77 for the city: margaride
# ---------------------------------------
# Processing record 78 for the city: kirakira
# ---------------------------------------
# Processing record 79 for the city: ilulissat
# ---------------------------------------
# grand river south east not found in OpenWeather database.
# ---------------------------------------
# Processing record 81 for the city: popondetta
# ---------------------------------------
# Processing record 82 for the city: huarmey
# ---------------------------------------
# Processing record 83 for the city: bafq
# ---------------------------------------
# Processing record 84 for the city: punta arenas
# ---------------------------------------
# Processing record 85 for the city: kambove
# ---------------------------------------
# Processing record 86 for the city: avera
# ---------------------------------------
# Processing record 87 for the city: verkhnevilyuysk
# ---------------------------------------
# Processing record 88 for the city: bredasdorp
# ---------------------------------------
# Processing record 89 for the city: port augusta
# ---------------------------------------
# Processing record 90 for the city: bluff
# ---------------------------------------
# Processing record 91 for the city: cherskiy
# ---------------------------------------
# Processing record 92 for the city: haverfordwest
# ---------------------------------------
# Processing record 93 for the city: arraial do cabo
# ---------------------------------------
# Processing record 94 for the city: cairo
# ---------------------------------------
# Processing record 95 for the city: esperance
# ---------------------------------------
# Processing record 96 for the city: atuona
# ---------------------------------------
# Processing record 97 for the city: port alfred
# ---------------------------------------
# Processing record 98 for the city: sao filipe
# ---------------------------------------
# Processing record 99 for the city: champerico
# ---------------------------------------
# Processing record 100 for the city: necochea
# ---------------------------------------
# tsihombe not found in OpenWeather database.
# ---------------------------------------
# Processing record 102 for the city: longyearbyen
# ---------------------------------------
# Processing record 103 for the city: perth
# ---------------------------------------
# Processing record 104 for the city: east london
# ---------------------------------------
# Processing record 105 for the city: lompoc
# ---------------------------------------
# Processing record 106 for the city: yellowknife
# ---------------------------------------
# Processing record 107 for the city: skjervoy
# ---------------------------------------
# Processing record 108 for the city: lebu
# ---------------------------------------
# Processing record 109 for the city: buluang
# ---------------------------------------
# Processing record 110 for the city: martapura
# ---------------------------------------
# Processing record 111 for the city: new norfolk
# ---------------------------------------
# Processing record 112 for the city: roald
# ---------------------------------------
# Processing record 113 for the city: flinders
# ---------------------------------------
# acuna not found in OpenWeather database.
# ---------------------------------------
# Processing record 115 for the city: hasaki
# ---------------------------------------
# Processing record 116 for the city: trairi
# ---------------------------------------
# Processing record 117 for the city: broome
# ---------------------------------------
# Processing record 118 for the city: sorland
# ---------------------------------------
# Processing record 119 for the city: florina
# ---------------------------------------
# Processing record 120 for the city: kalmunai
# ---------------------------------------
# antagan not found in OpenWeather database.
# ---------------------------------------
# Processing record 122 for the city: jamestown
# ---------------------------------------
# Processing record 123 for the city: arlit
# ---------------------------------------
# Processing record 124 for the city: srandakan
# ---------------------------------------
# Processing record 125 for the city: sao jose da coroa grande
# ---------------------------------------
# Processing record 126 for the city: marrakesh
# ---------------------------------------
# Processing record 127 for the city: tautira
# ---------------------------------------
# Processing record 128 for the city: dandong
# ---------------------------------------
# Processing record 129 for the city: komsomolskiy
# ---------------------------------------
# Processing record 130 for the city: cayenne
# ---------------------------------------
# shkotovo-26 not found in OpenWeather database.
# ---------------------------------------
# Processing record 132 for the city: chokurdakh
# ---------------------------------------
# Processing record 133 for the city: galle
# ---------------------------------------
# Processing record 134 for the city: plettenberg bay
# ---------------------------------------
# Processing record 135 for the city: hami
# ---------------------------------------
# Processing record 136 for the city: kokkola
# ---------------------------------------
# Processing record 137 for the city: sakakah
# ---------------------------------------
# Processing record 138 for the city: victoria
# ---------------------------------------
# sentyabrskiy not found in OpenWeather database.
# ---------------------------------------
# Processing record 140 for the city: ribeira grande
# ---------------------------------------
# ngukurr not found in OpenWeather database.
# ---------------------------------------
# Processing record 142 for the city: tabuk
# ---------------------------------------
# Processing record 143 for the city: katangli
# ---------------------------------------
# Processing record 144 for the city: kodiak
# ---------------------------------------
# Processing record 145 for the city: sekondi
# ---------------------------------------
# Processing record 146 for the city: arvika
# ---------------------------------------
# Processing record 147 for the city: kondinskoye
# ---------------------------------------
# Processing record 148 for the city: nowy dwor gdanski
# ---------------------------------------
# Processing record 149 for the city: yomou
# ---------------------------------------
# Processing record 150 for the city: hambantota
# ---------------------------------------
# Processing record 151 for the city: praia da vitoria
# ---------------------------------------
# Processing record 152 for the city: hithadhoo
# ---------------------------------------
# Processing record 153 for the city: ucluelet
# ---------------------------------------
# Processing record 154 for the city: lahad datu
# ---------------------------------------
# Processing record 155 for the city: takaka
# ---------------------------------------
# Processing record 156 for the city: nikolskoye
# ---------------------------------------
# Processing record 157 for the city: valparaiso
# ---------------------------------------
# umzimvubu not found in OpenWeather database.
# ---------------------------------------
# phan rang not found in OpenWeather database.
# ---------------------------------------
# Processing record 160 for the city: emerald
# ---------------------------------------
# Processing record 161 for the city: butaritari
# ---------------------------------------
# Processing record 162 for the city: katsuura
# ---------------------------------------
# Processing record 163 for the city: grand gaube
# ---------------------------------------
# Processing record 164 for the city: trapani
# ---------------------------------------
# Processing record 165 for the city: constitucion
# ---------------------------------------
# Processing record 166 for the city: lufilufi
# ---------------------------------------
# Processing record 167 for the city: greenville
# ---------------------------------------
# Processing record 168 for the city: nisia floresta
# ---------------------------------------
# Processing record 169 for the city: sangar
# ---------------------------------------
# Processing record 170 for the city: bjornevatn
# ---------------------------------------
# samusu not found in OpenWeather database.
# ---------------------------------------
# Processing record 172 for the city: saint-philippe
# ---------------------------------------
# Processing record 173 for the city: nandu
# ---------------------------------------
# Processing record 174 for the city: kutahya
# ---------------------------------------
# Processing record 175 for the city: ancud
# ---------------------------------------
# Processing record 176 for the city: townsville
# ---------------------------------------
# Processing record 177 for the city: myitkyina
# ---------------------------------------
# Processing record 178 for the city: saint george
# ---------------------------------------
# Processing record 179 for the city: naze
# ---------------------------------------
# Processing record 180 for the city: hazorasp
# ---------------------------------------
# Processing record 181 for the city: biltine
# ---------------------------------------
# Processing record 182 for the city: saskylakh
# ---------------------------------------
# Processing record 183 for the city: provideniya
# ---------------------------------------
# Processing record 184 for the city: mandalgovi
# ---------------------------------------
# Processing record 185 for the city: togur
# ---------------------------------------
# Processing record 186 for the city: saint-francois
# ---------------------------------------
# Processing record 187 for the city: petropavlovsk-kamchatskiy
# ---------------------------------------
# Processing record 188 for the city: yarovoye
# ---------------------------------------
# Processing record 189 for the city: torbay
# ---------------------------------------
# Processing record 190 for the city: vaini
# ---------------------------------------
# Processing record 191 for the city: ayan
# ---------------------------------------
# Processing record 192 for the city: north bend
# ---------------------------------------
# Processing record 193 for the city: inhambane
# ---------------------------------------
# Processing record 194 for the city: hobart
# ---------------------------------------
# Processing record 195 for the city: perbaungan
# ---------------------------------------
# Processing record 196 for the city: calderitas
# ---------------------------------------
# Processing record 197 for the city: flin flon
# ---------------------------------------
# amderma not found in OpenWeather database.
# ---------------------------------------
# Processing record 199 for the city: ilo
# ---------------------------------------
# Processing record 200 for the city: campo formoso
# ---------------------------------------
# Processing record 201 for the city: juba
# ---------------------------------------
# Processing record 202 for the city: newport
# ---------------------------------------
# Processing record 203 for the city: bathsheba
# ---------------------------------------
# mrirt not found in OpenWeather database.
# ---------------------------------------
# Processing record 205 for the city: nemuro
# ---------------------------------------
# Processing record 206 for the city: berlevag
# ---------------------------------------
# Processing record 207 for the city: bharatpur
# ---------------------------------------
# Processing record 208 for the city: pucallpa
# ---------------------------------------
# bokspits not found in OpenWeather database.
# ---------------------------------------
# Processing record 210 for the city: martinez
# ---------------------------------------
# Processing record 211 for the city: road town
# ---------------------------------------
# Processing record 212 for the city: pevek
# ---------------------------------------
# yanchukan not found in OpenWeather database.
# ---------------------------------------
# Processing record 214 for the city: sao joao da barra
# ---------------------------------------
# Processing record 215 for the city: mar del plata
# ---------------------------------------
# Processing record 216 for the city: skole
# ---------------------------------------
# Processing record 217 for the city: mountain home
# ---------------------------------------
# Processing record 218 for the city: coihaique
# ---------------------------------------
# Processing record 219 for the city: birin
# ---------------------------------------
# Processing record 220 for the city: langtad
# ---------------------------------------
# Processing record 221 for the city: susehri
# ---------------------------------------
# huitzuco not found in OpenWeather database.
# ---------------------------------------
# Processing record 223 for the city: marsh harbour
# ---------------------------------------
# Processing record 224 for the city: rindal
# ---------------------------------------
# Processing record 225 for the city: dicabisagan
# ---------------------------------------
# Processing record 226 for the city: padang
# ---------------------------------------
# kamenskoye not found in OpenWeather database.
# ---------------------------------------
# Processing record 228 for the city: doha
# ---------------------------------------
# Processing record 229 for the city: leningradskiy
# ---------------------------------------
# Processing record 230 for the city: meulaboh
# ---------------------------------------
# Processing record 231 for the city: jaru
# ---------------------------------------
# Processing record 232 for the city: namatanai
# ---------------------------------------
# Processing record 233 for the city: baglung
# ---------------------------------------
# Processing record 234 for the city: bodo
# ---------------------------------------
# Processing record 235 for the city: burhanpur
# ---------------------------------------
# Processing record 236 for the city: ritchie
# ---------------------------------------
# Processing record 237 for the city: pisco
# ---------------------------------------
# Processing record 238 for the city: surt
# ---------------------------------------
# Processing record 239 for the city: chapais
# ---------------------------------------
# Processing record 240 for the city: vestmannaeyjar
# ---------------------------------------
# Processing record 241 for the city: lampang
# ---------------------------------------
# Processing record 242 for the city: kamina
# ---------------------------------------
# Processing record 243 for the city: ekimchan
# ---------------------------------------
# Processing record 244 for the city: westport
# ---------------------------------------
# Processing record 245 for the city: sao gabriel da cachoeira
# ---------------------------------------
# Processing record 246 for the city: intipuca
# ---------------------------------------
# Processing record 247 for the city: mount gambier
# ---------------------------------------
# Processing record 248 for the city: bundibugyo
# ---------------------------------------
# Processing record 249 for the city: poltavka
# ---------------------------------------
# Processing record 250 for the city: san francisco
# ---------------------------------------
# Processing record 251 for the city: ferry pass
# ---------------------------------------
# Processing record 252 for the city: pokhara
# ---------------------------------------
# Processing record 253 for the city: waipawa
# ---------------------------------------
# Processing record 254 for the city: siva
# ---------------------------------------
# Processing record 255 for the city: qaanaaq
# ---------------------------------------
# Processing record 256 for the city: moerai
# ---------------------------------------
# Processing record 257 for the city: kavaratti
# ---------------------------------------
# Processing record 258 for the city: gazojak
# ---------------------------------------
# karaul not found in OpenWeather database.
# ---------------------------------------
# Processing record 260 for the city: dali
# ---------------------------------------
# warqla not found in OpenWeather database.
# ---------------------------------------
# Processing record 262 for the city: caravelas
# ---------------------------------------
# Processing record 263 for the city: chivay
# ---------------------------------------
# Processing record 264 for the city: umtata
# ---------------------------------------
# Processing record 265 for the city: clyde river
# ---------------------------------------
# Processing record 266 for the city: nanortalik
# ---------------------------------------
# Processing record 267 for the city: tessalit
# ---------------------------------------
# Processing record 268 for the city: darapidap
# ---------------------------------------
# Processing record 269 for the city: dawlatabad
# ---------------------------------------
# mullaitivu not found in OpenWeather database.
# ---------------------------------------
# Processing record 271 for the city: cidreira
# ---------------------------------------
# Processing record 272 for the city: awbari
# ---------------------------------------
# Processing record 273 for the city: beringovskiy
# ---------------------------------------
# Processing record 274 for the city: gweta
# ---------------------------------------
# Processing record 275 for the city: gaoual
# ---------------------------------------
# ituni not found in OpenWeather database.
# ---------------------------------------
# Processing record 277 for the city: urucara
# ---------------------------------------
# Processing record 278 for the city: petershagen
# ---------------------------------------
# Processing record 279 for the city: batagay
# ---------------------------------------
# Processing record 280 for the city: aykhal
# ---------------------------------------
# Processing record 281 for the city: penzance
# ---------------------------------------
# Processing record 282 for the city: lyubinskiy
# ---------------------------------------
# Processing record 283 for the city: marawi
# ---------------------------------------
# Processing record 284 for the city: sarkand
# ---------------------------------------
# bur gabo not found in OpenWeather database.
# ---------------------------------------
# Processing record 286 for the city: havoysund
# ---------------------------------------
# Processing record 287 for the city: pangnirtung
# ---------------------------------------
# Processing record 288 for the city: fortuna
# ---------------------------------------
# Processing record 289 for the city: guanaja
# ---------------------------------------
# Processing record 290 for the city: umba
# ---------------------------------------
# Processing record 291 for the city: togitsu
# ---------------------------------------
# Processing record 292 for the city: kruisfontein
# ---------------------------------------
# Processing record 293 for the city: ostrovnoy
# ---------------------------------------
# Processing record 294 for the city: byron bay
# ---------------------------------------
# Processing record 295 for the city: brae
# ---------------------------------------
# Processing record 296 for the city: centralia
# ---------------------------------------
# mys shmidta not found in OpenWeather database.
# ---------------------------------------
# Processing record 298 for the city: moses lake
# ---------------------------------------
# lolua not found in OpenWeather database.
# ---------------------------------------
# tasbuget not found in OpenWeather database.
# ---------------------------------------
# Processing record 301 for the city: aklavik
# ---------------------------------------
# Processing record 302 for the city: mounana
# ---------------------------------------
# Processing record 303 for the city: tuatapere
# ---------------------------------------
# Processing record 304 for the city: mount isa
# ---------------------------------------
# Processing record 305 for the city: warrington
# ---------------------------------------
# Processing record 306 for the city: prado
# ---------------------------------------
# Processing record 307 for the city: am timan
# ---------------------------------------
# Processing record 308 for the city: turkan
# ---------------------------------------
# Processing record 309 for the city: ierapetra
# ---------------------------------------
# Processing record 310 for the city: lata
# ---------------------------------------
# Processing record 311 for the city: vao
# ---------------------------------------
# Processing record 312 for the city: bhadrachalam
# ---------------------------------------
# Processing record 313 for the city: yaan
# ---------------------------------------
# Processing record 314 for the city: pacific grove
# ---------------------------------------
# Processing record 315 for the city: sitka
# ---------------------------------------
# Processing record 316 for the city: marinette
# ---------------------------------------
# Processing record 317 for the city: camoapa
# ---------------------------------------
# Processing record 318 for the city: laguna
# ---------------------------------------
# Processing record 319 for the city: roseto degli abruzzi
# ---------------------------------------
# Processing record 320 for the city: tarabuco
# ---------------------------------------
# Processing record 321 for the city: hangu
# ---------------------------------------
# Processing record 322 for the city: sorong
# ---------------------------------------
# Processing record 323 for the city: ketchikan
# ---------------------------------------
# Processing record 324 for the city: cap malheureux
# ---------------------------------------
# Processing record 325 for the city: bull savanna
# ---------------------------------------
# Processing record 326 for the city: vestmanna
# ---------------------------------------
# Processing record 327 for the city: natal
# ---------------------------------------
# Processing record 328 for the city: urengoy
# ---------------------------------------
# Processing record 329 for the city: elizabeth city
# ---------------------------------------
# Processing record 330 for the city: san patricio
# ---------------------------------------
# Processing record 331 for the city: chanute
# ---------------------------------------
# Processing record 332 for the city: uvinza
# ---------------------------------------
# samalaeulu not found in OpenWeather database.
# ---------------------------------------
# Processing record 334 for the city: kamaishi
# ---------------------------------------
# Processing record 335 for the city: harper
# ---------------------------------------
# Processing record 336 for the city: san roque
# ---------------------------------------
# Processing record 337 for the city: aberdare
# ---------------------------------------
# Processing record 338 for the city: tamandare
# ---------------------------------------
# Processing record 339 for the city: olafsvik
# ---------------------------------------
# Processing record 340 for the city: airai
# ---------------------------------------
# Processing record 341 for the city: watertown
# ---------------------------------------
# Processing record 342 for the city: la rioja
# ---------------------------------------
# Processing record 343 for the city: sisimiut
# ---------------------------------------
# Processing record 344 for the city: mayo
# ---------------------------------------
# attawapiskat not found in OpenWeather database.
# ---------------------------------------
# Processing record 346 for the city: port blair
# ---------------------------------------
# Processing record 347 for the city: sioux lookout
# ---------------------------------------
# Processing record 348 for the city: yarmouth
# ---------------------------------------
# Processing record 349 for the city: boueni
# ---------------------------------------
# Processing record 350 for the city: lahaina
# ---------------------------------------
# Processing record 351 for the city: deputatskiy
# ---------------------------------------
# Processing record 352 for the city: banjarmasin
# ---------------------------------------
# mocambique not found in OpenWeather database.
# ---------------------------------------
# Processing record 354 for the city: lom sak
# ---------------------------------------
# Processing record 355 for the city: san cristobal
# ---------------------------------------
# Processing record 356 for the city: port shepstone
# ---------------------------------------
# Processing record 357 for the city: imbituba
# ---------------------------------------
# Processing record 358 for the city: belmonte
# ---------------------------------------
# Processing record 359 for the city: mucurapo
# ---------------------------------------
# Processing record 360 for the city: haukipudas
# ---------------------------------------
# Processing record 361 for the city: vitim
# ---------------------------------------
# Processing record 362 for the city: yuzhou
# ---------------------------------------
# kazalinsk not found in OpenWeather database.
# ---------------------------------------
# Processing record 364 for the city: alamor
# ---------------------------------------
# Processing record 365 for the city: sokoto
# ---------------------------------------
# Processing record 366 for the city: takoradi
# ---------------------------------------
# Processing record 367 for the city: ishigaki
# ---------------------------------------
# Processing record 368 for the city: luanda
# ---------------------------------------
# toliary not found in OpenWeather database.
# ---------------------------------------
# Processing record 370 for the city: northam
# ---------------------------------------
# Processing record 371 for the city: aasiaat
# ---------------------------------------
# Processing record 372 for the city: careiro da varzea
# ---------------------------------------
# burica not found in OpenWeather database.
# ---------------------------------------
# nizhneyansk not found in OpenWeather database.
# ---------------------------------------
# Processing record 375 for the city: saint-pierre
# ---------------------------------------
# Processing record 376 for the city: camamu
# ---------------------------------------
# Processing record 377 for the city: yaransk
# ---------------------------------------
# Processing record 378 for the city: atikokan
# ---------------------------------------
# Processing record 379 for the city: geraldton
# ---------------------------------------
# Processing record 380 for the city: nikolayevsk-na-amure
# ---------------------------------------
# Processing record 381 for the city: ahuimanu
# ---------------------------------------
# Processing record 382 for the city: kautokeino
# ---------------------------------------
# Processing record 383 for the city: honningsvag
# ---------------------------------------
# Processing record 384 for the city: pangkalanbuun
# ---------------------------------------
# Processing record 385 for the city: muros
# ---------------------------------------
# Processing record 386 for the city: henties bay
# ---------------------------------------
# Processing record 387 for the city: oga
# ---------------------------------------
# Processing record 388 for the city: kyabram
# ---------------------------------------
# Processing record 389 for the city: khash
# ---------------------------------------
# Processing record 390 for the city: barao de melgaco
# ---------------------------------------
# Processing record 391 for the city: tura
# ---------------------------------------
# Processing record 392 for the city: kiama
# ---------------------------------------
# Processing record 393 for the city: malartic
# ---------------------------------------
# Processing record 394 for the city: upata
# ---------------------------------------
# Processing record 395 for the city: vostok
# ---------------------------------------
# Processing record 396 for the city: khani
# ---------------------------------------
# Processing record 397 for the city: motzorongo
# ---------------------------------------
# Processing record 398 for the city: san pedro
# ---------------------------------------
# Processing record 399 for the city: piacabucu
# ---------------------------------------
# Processing record 400 for the city: yatou
# ---------------------------------------
# vaitupu not found in OpenWeather database.
# ---------------------------------------
# Processing record 402 for the city: te anau
# ---------------------------------------
# Processing record 403 for the city: igarka
# ---------------------------------------
# Processing record 404 for the city: tongzi
# ---------------------------------------
# Processing record 405 for the city: santa cruz
# ---------------------------------------
# Processing record 406 for the city: letterkenny
# ---------------------------------------
# Processing record 407 for the city: half moon bay
# ---------------------------------------
# tubruq not found in OpenWeather database.
# ---------------------------------------
# Processing record 409 for the city: ransang
# ---------------------------------------
# Processing record 410 for the city: peniche
# ---------------------------------------
# Processing record 411 for the city: georgetown
# ---------------------------------------
# Processing record 412 for the city: krasnyy yar
# ---------------------------------------
# Processing record 413 for the city: udachnyy
# ---------------------------------------
# Processing record 414 for the city: katherine
# ---------------------------------------
# Processing record 415 for the city: margate
# ---------------------------------------
# Processing record 416 for the city: usinsk
# ---------------------------------------
# Processing record 417 for the city: conway
# ---------------------------------------
# Processing record 418 for the city: dunedin
# ---------------------------------------
# Processing record 419 for the city: santa ana huista
# ---------------------------------------
# Processing record 420 for the city: daru
# ---------------------------------------
# Processing record 421 for the city: rajsamand
# ---------------------------------------
# Processing record 422 for the city: bereda
# ---------------------------------------
# Processing record 423 for the city: haines junction
# ---------------------------------------
# Processing record 424 for the city: ndioum
# ---------------------------------------
# Processing record 425 for the city: kahului
# ---------------------------------------
# Processing record 426 for the city: port hardy
# ---------------------------------------
# Processing record 427 for the city: muli
# ---------------------------------------
# Processing record 428 for the city: pimentel
# ---------------------------------------
# Processing record 429 for the city: nishihara
# ---------------------------------------
# Processing record 430 for the city: jashpurnagar
# ---------------------------------------
# Processing record 431 for the city: port elizabeth
# ---------------------------------------
# Processing record 432 for the city: vila franca do campo
# ---------------------------------------
# Processing record 433 for the city: vardo
# ---------------------------------------
# Processing record 434 for the city: bom jesus da lapa
# ---------------------------------------
# Processing record 435 for the city: aleksandrov gay
# ---------------------------------------
# Processing record 436 for the city: guerrero negro
# ---------------------------------------
# Processing record 437 for the city: cabra
# ---------------------------------------
# Processing record 438 for the city: little current
# ---------------------------------------
# Processing record 439 for the city: bambous virieux
# ---------------------------------------
# Processing record 440 for the city: horta
# ---------------------------------------
# kadykchan not found in OpenWeather database.
# ---------------------------------------
# Processing record 442 for the city: namibe
# ---------------------------------------
# Processing record 443 for the city: salinas
# ---------------------------------------
# Processing record 444 for the city: aksu
# ---------------------------------------
# Processing record 445 for the city: hofn
# ---------------------------------------
# Processing record 446 for the city: tadine
# ---------------------------------------
# Processing record 447 for the city: prince rupert
# ---------------------------------------
# Processing record 448 for the city: tanout
# ---------------------------------------
# Processing record 449 for the city: phulabani
# ---------------------------------------
# Processing record 450 for the city: portel
# ---------------------------------------
# tumannyy not found in OpenWeather database.
# ---------------------------------------
# Processing record 452 for the city: souillac
# ---------------------------------------
# Processing record 453 for the city: camacupa
# ---------------------------------------
# Processing record 454 for the city: mittersill
# ---------------------------------------
# Processing record 455 for the city: yerbogachen
# ---------------------------------------
# Processing record 456 for the city: severo-kurilsk
# ---------------------------------------
# Processing record 457 for the city: guaymas
# ---------------------------------------
# Processing record 458 for the city: kaseda
# ---------------------------------------
# Processing record 459 for the city: taupo
# ---------------------------------------
# Processing record 460 for the city: husavik
# ---------------------------------------
# Processing record 461 for the city: cuamba
# ---------------------------------------
# Processing record 462 for the city: vieques
# ---------------------------------------
# Processing record 463 for the city: mackenzie
# ---------------------------------------
# Processing record 464 for the city: khabarovsk
# ---------------------------------------
# Processing record 465 for the city: atlantic city
# ---------------------------------------
# Processing record 466 for the city: sucua
# ---------------------------------------
# Processing record 467 for the city: pastavy
# ---------------------------------------
# Processing record 468 for the city: eslov
# ---------------------------------------
# Processing record 469 for the city: yichun
# ---------------------------------------
# Processing record 470 for the city: yeppoon
# ---------------------------------------
# Processing record 471 for the city: morgan city
# ---------------------------------------
# Processing record 472 for the city: morondava
# ---------------------------------------
# Processing record 473 for the city: luzino
# ---------------------------------------
# Processing record 474 for the city: vila
# ---------------------------------------
# Processing record 475 for the city: aswan
# ---------------------------------------
# Processing record 476 for the city: cape canaveral
# ---------------------------------------
# Processing record 477 for the city: diamantino
# ---------------------------------------
# Processing record 478 for the city: kilindoni
# ---------------------------------------
# Processing record 479 for the city: nevelsk
# ---------------------------------------
# Processing record 480 for the city: mogwase
# ---------------------------------------
# Processing record 481 for the city: karpogory
# ---------------------------------------
# Processing record 482 for the city: eureka
# ---------------------------------------
# Processing record 483 for the city: tayoltita
# ---------------------------------------
# Processing record 484 for the city: huilong
# ---------------------------------------
# Processing record 485 for the city: arawa
# ---------------------------------------
# Processing record 486 for the city: codrington
# ---------------------------------------
# Processing record 487 for the city: coaldale
# ---------------------------------------
# Processing record 488 for the city: kuching
# ---------------------------------------
# Processing record 489 for the city: shingu
# ---------------------------------------
# Processing record 490 for the city: linxia
# ---------------------------------------
# Processing record 491 for the city: itoman
# ---------------------------------------
# Processing record 492 for the city: durban
# ---------------------------------------
# Processing record 493 for the city: visby
# ---------------------------------------
# ayoquezco not found in OpenWeather database.
# ---------------------------------------
# Processing record 495 for the city: broken hill
# ---------------------------------------
# Processing record 496 for the city: cheremkhovo
# ---------------------------------------
# Processing record 497 for the city: kota kinabalu
# ---------------------------------------
# Processing record 498 for the city: yuanping
# ---------------------------------------
# Processing record 499 for the city: chumikan
# ---------------------------------------
# Processing record 500 for the city: banfora
# ---------------------------------------
# Processing record 501 for the city: srednekolymsk
# ---------------------------------------
# Processing record 502 for the city: aranda de duero
# ---------------------------------------
# Processing record 503 for the city: alugan
# ---------------------------------------
# Processing record 504 for the city: palmer
# ---------------------------------------
# Processing record 505 for the city: port-gentil
# ---------------------------------------
# Processing record 506 for the city: alofi
# ---------------------------------------
# Processing record 507 for the city: wajid
# ---------------------------------------
# Processing record 508 for the city: tefe
# ---------------------------------------
# Processing record 509 for the city: madang
# ---------------------------------------
# Processing record 510 for the city: los llanos de aridane
# ---------------------------------------
# Processing record 511 for the city: wellington
# ---------------------------------------
# Processing record 512 for the city: saint-augustin
# ---------------------------------------
# Processing record 513 for the city: nybro
# ---------------------------------------
# Processing record 514 for the city: vero beach
# ---------------------------------------
# Processing record 515 for the city: waingapu
# ---------------------------------------
# Processing record 516 for the city: male
# ---------------------------------------
# Processing record 517 for the city: zhuhai
# ---------------------------------------
# Processing record 518 for the city: nerja
# ---------------------------------------
# Processing record 519 for the city: loa janan
# ---------------------------------------
# Processing record 520 for the city: phuket
# ---------------------------------------
# Processing record 521 for the city: pingliang
# ---------------------------------------
# Processing record 522 for the city: yar-sale
# ---------------------------------------
# Processing record 523 for the city: qasigiannguit
# ---------------------------------------
# Processing record 524 for the city: new glasgow
# ---------------------------------------
# Processing record 525 for the city: suffolk
# ---------------------------------------
# Processing record 526 for the city: contamana
# ---------------------------------------
# Processing record 527 for the city: sainte-marie
# ---------------------------------------
# Processing record 528 for the city: figeac
# ---------------------------------------
# Processing record 529 for the city: kijang
# ---------------------------------------
# Processing record 530 for the city: hamilton
# ---------------------------------------
# Processing record 531 for the city: bowmore
# ---------------------------------------
# Processing record 532 for the city: kloulklubed
# ---------------------------------------
# Processing record 533 for the city: karratha
# ---------------------------------------
# Processing record 534 for the city: raudeberg
# ---------------------------------------
# Processing record 535 for the city: santo domingo
# ---------------------------------------
# Processing record 536 for the city: viedma
# ---------------------------------------
# Processing record 537 for the city: songea
# ---------------------------------------
# Processing record 538 for the city: bokhan
# ---------------------------------------
# Processing record 539 for the city: nizhnekamsk
# ---------------------------------------
# Processing record 540 for the city: puerto escondido
# ---------------------------------------
# Processing record 541 for the city: kieta
# ---------------------------------------
# Processing record 542 for the city: blagoyevo
# ---------------------------------------
# Processing record 543 for the city: majene
# ---------------------------------------
# Processing record 544 for the city: kurchum
# ---------------------------------------
# Processing record 545 for the city: cortez
# ---------------------------------------
# Processing record 546 for the city: ngaoundere
# ---------------------------------------
# Processing record 547 for the city: fairbanks
# ---------------------------------------
# Processing record 548 for the city: trenggalek
# ---------------------------------------
# Processing record 549 for the city: port hedland
# ---------------------------------------
# Processing record 550 for the city: cirebon
# ---------------------------------------
# Processing record 551 for the city: marovoay
# ---------------------------------------
# Processing record 552 for the city: vanderhoof
# ---------------------------------------
# Processing record 553 for the city: neuquen
# ---------------------------------------
# Processing record 554 for the city: bar harbor
# ---------------------------------------
# Processing record 555 for the city: gloversville
# ---------------------------------------
# Processing record 556 for the city: brigantine
# ---------------------------------------
# Processing record 557 for the city: ahipara
# ---------------------------------------
# marv dasht not found in OpenWeather database.
# ---------------------------------------
# Processing record 559 for the city: tezu
# ---------------------------------------
# Processing record 560 for the city: poum
# ---------------------------------------
# Processing record 561 for the city: acarau
# ---------------------------------------
# ust-bolsheretsk not found in OpenWeather database.
# ---------------------------------------
# Processing record 563 for the city: comodoro rivadavia
# ---------------------------------------
# Processing record 564 for the city: jega
# ---------------------------------------
# Processing record 565 for the city: marienburg
# ---------------------------------------
# Processing record 566 for the city: ergani
# ---------------------------------------
# Processing record 567 for the city: nanchong
# ---------------------------------------
# Processing record 568 for the city: maniitsoq
# ---------------------------------------
# Processing record 569 for the city: panjab
# ---------------------------------------
# satitoa not found in OpenWeather database.
# ---------------------------------------
# Processing record 571 for the city: iranshahr
# ---------------------------------------
# Processing record 572 for the city: akdepe
# ---------------------------------------
# Processing record 573 for the city: beaufort
# ---------------------------------------
# Processing record 574 for the city: yining
# ---------------------------------------
# Processing record 575 for the city: pilibanga
# ---------------------------------------
# Processing record 576 for the city: wufeng
# ---------------------------------------
# Processing record 577 for the city: tuy hoa
# ---------------------------------------
# Processing record 578 for the city: klaksvik
# ---------------------------------------
# Processing record 579 for the city: quatre cocos
# ---------------------------------------
# Processing record 580 for the city: lasa
# ---------------------------------------
# Processing record 581 for the city: port-cartier
# ---------------------------------------
# Processing record 582 for the city: bosaso
# ---------------------------------------
# Processing record 583 for the city: soddy-daisy
# ---------------------------------------
# Processing record 584 for the city: kindu
# ---------------------------------------
# bargal not found in OpenWeather database.
# ---------------------------------------
# Processing record 586 for the city: egvekinot
# ---------------------------------------
# Processing record 587 for the city: campbellsville
# ---------------------------------------
# Processing record 588 for the city: tekeli
# ---------------------------------------
# Processing record 589 for the city: prince albert
# ---------------------------------------
# Processing record 590 for the city: chupa
# ---------------------------------------
# Processing record 591 for the city: hokitika
# ---------------------------------------
# Processing record 592 for the city: shitanjing
# ---------------------------------------
# Processing record 593 for the city: azul
# ---------------------------------------
# Processing record 594 for the city: wanning
# ---------------------------------------
# Processing record 595 for the city: weston-super-mare
# ---------------------------------------
# Processing record 596 for the city: piracanjuba
# ---------------------------------------
# Processing record 597 for the city: aloha
# ---------------------------------------
# uzumlu not found in OpenWeather database.
# ---------------------------------------
# Processing record 599 for the city: abu kamal
# ---------------------------------------
# Processing record 600 for the city: kilingi-nomme
# ---------------------------------------
# Processing record 601 for the city: luang prabang
# ---------------------------------------
# Processing record 602 for the city: labuhan
# ---------------------------------------
# Processing record 603 for the city: amazar
# ---------------------------------------
# Processing record 604 for the city: kikwit
# ---------------------------------------
# Processing record 605 for the city: russell
# ---------------------------------------
# Processing record 606 for the city: zdvinsk
# ---------------------------------------
# Processing record 607 for the city: camacha
# ---------------------------------------
# Processing record 608 for the city: bouna
# ---------------------------------------
# Processing record 609 for the city: goderich
# ---------------------------------------
# Processing record 610 for the city: aloleng
# ---------------------------------------
# Processing record 611 for the city: zhirnovsk
# ---------------------------------------
# Processing record 612 for the city: nicoya
# ---------------------------------------
# Processing record 613 for the city: pyu
# ---------------------------------------
# Processing record 614 for the city: hudson bay
# ---------------------------------------
# Processing record 615 for the city: kanniyakumari
# ---------------------------------------
# Processing record 616 for the city: jadu
# ---------------------------------------
# Processing record 617 for the city: teahupoo
# ---------------------------------------
# Processing record 618 for the city: lavrentiya
# ---------------------------------------
# Processing record 619 for the city: mazamari
# ---------------------------------------
# Processing record 620 for the city: danane
# ---------------------------------------
# Processing record 621 for the city: oranjemund
# ---------------------------------------
# Processing record 622 for the city: mumford
# ---------------------------------------
# Processing record 623 for the city: dong hoi
# ---------------------------------------

# %%
len(search_data)
# Out:
# 623

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, temp, humidity, cloudiness, and wind speed.
weather_dict = {
    "City": city_name,
    "Latitude": lat,
    "Temperature (F)": temp_max,
    "Humidity (%)": humidity,
    "Cloudiness (%)": clouds,
    "Wind Speed (mph)": wind_speed,
    "Date": data_date
    
}
weather_data = pd.DataFrame(weather_dict)

#Export weather data to csv.
weather_data.to_csv("weather_data.csv", encoding="utf-8", index=False)

#Display df.
weather_data.head()
# Out:
#         City  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0  Cape Town  -33.9258            69.01            88              75
# 1       Chui  -33.6971            78.39            69             100
# 2     Anadyr   64.7500            -5.01            77              40
# 3    Rikitea  -23.1203            78.49            67              41
# 4   Thompson   55.7435             5.00            78              75
#
#    Wind Speed (mph)        Date
# 0             12.66  1610742283
# 1             16.69  1610742533
# 2              8.95  1610742533
# 3              6.91  1610742533
# 4              4.61  1610742363

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hi_hum = weather_data.loc[weather_data['Humidity (%)'] > 100]
print(hi_hum)
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph)]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Temperature (F)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Maximum Temperature (F) by Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('world_temp_lat.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Humidity (%)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Humidity by Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('world_hum_lat.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Cloudiness (%)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Cloudiness by Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('world_clouds_lat.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['Latitude']
y_values = weather_data['Wind Speed (mph)']

plt.figure(1, figsize=(10, 6))
plt.scatter(x_values, y_values)
plt.xlim(-90,90,10)
plt.title('Wind Speed by Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('world_wspeed_lat.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
nh_data = weather_data.loc[weather_data['Latitude'] >=0]
sh_data = weather_data.loc[weather_data['Latitude'] <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
#   File "<ipython-input-50-de086e2ec633>", line 9
#     Note: the values in parentheses tell the computer where to place the line equation formula (x-coordinate, y-coordinate
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
